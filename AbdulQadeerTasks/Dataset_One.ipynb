# %% [markdown]
# ## Importing libraries

# %%
from scipy.io import arff
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.impute import SimpleImputer

# %% [markdown]
# ## Loading .arff type files

# %%
df = arff.loadarff('1year.arff')
df = pd.DataFrame(df[0])

# %%
df.sample(5)
# Out:
#          Attr1    Attr2    Attr3    Attr4     Attr5     Attr6     Attr7  \
# 3169  0.109970  0.56484 -0.04034  0.92858  -25.7470  0.109970  0.143990
# 3375  0.076408  0.77870 -0.38147  0.51012  -46.1230  0.000000  0.095802
# 6683  0.237270  0.73362  0.26638  1.36310    7.4458 -0.025436  0.301370
# 4367  0.149680  0.18502  0.38591  3.18590  109.7700  0.000000  0.184910
# 5274  0.006537  0.72383  0.10615  1.14730    8.6947  0.145400  0.006537
#
#         Attr8   Attr9   Attr10  ...    Attr56    Attr57   Attr58    Attr59  \
# 3169  0.77037  1.0766  0.43513  ...  0.071107  0.252720  0.92889  0.000000
# 3375  0.28419  3.5545  0.22130  ...  0.034248  0.345270  0.97308  0.000000
# 6683  0.36310  5.8933  0.26638  ...  0.036084  0.890740  0.95340  0.000000
# 4367  4.40480  1.0798  0.81498  ...  0.164740  0.183670  0.83091  0.000000
# 5274  0.38153  8.3844  0.27617  ...  0.256980  0.023669  1.01930  0.011864
#
#         Attr60   Attr61  Attr62   Attr63   Attr64  class
# 3169   21.5660   5.8640  86.896   4.2004   4.9896   b'0'
# 3375   75.8830  10.6100  79.963   4.5646   5.8969   b'0'
# 6683   52.8720   8.3506  45.437   8.0332      NaN   b'0'
# 4367    8.3901   5.3861  59.674   6.1166   2.4679   b'0'
# 5274  171.9800  11.5910  31.368  11.6360  48.3840   b'0'
#
# [5 rows x 65 columns]

# %% [markdown]
# ## Renaming input and target variable

# %%
# Rename input columns to X(n) format
input_columns = df.columns[:-1]  # Exclude the last column (target column)
renamed_input_columns = [f"X({n})" for n in range(1, len(input_columns) + 1)]
df.rename(columns=dict(zip(input_columns, renamed_input_columns)), inplace=True)

# Rename target column to 'Y'
df.rename(columns={'class': 'Y'}, inplace=True)

# %%
df.sample(5)
# Out:
#           X(1)     X(2)      X(3)     X(4)      X(5)      X(6)      X(7)  \
# 3919  0.026465  0.72860 -0.109300  0.84673  -30.0860  0.000000  0.029234
# 901   0.109150  0.67433  0.297010  1.44050   -9.1068  0.000000  0.137630
# 2362 -0.014557  0.82775  0.037916  1.05370  -35.2140 -0.010789 -0.014557
# 4112  0.172320  0.67991 -0.323110  0.41238 -102.8600  0.135440  0.222490
# 6059  0.152750  0.66203  0.203670  1.57210    7.9567  0.000000  0.152750
#
#          X(8)     X(9)    X(10)  ...     X(56)     X(57)    X(58)     X(59)  \
# 3919  0.37445  2.34030  0.27283  ...  0.021168  0.097001  0.98755  0.008793
# 901   0.48295  2.40990  0.32567  ...  0.059165  0.335140  0.94295  0.000000
# 2362  0.16503  0.98932  0.13660  ... -0.010797 -0.106570  1.01080  0.894280
# 4112  0.45979  1.16330  0.31262  ...  0.140390  0.551220  0.85961  0.415990
# 6059  0.51051  3.39180  0.33797  ...  0.148310  0.451970  0.85533  0.000000
#
#         X(60)    X(61)    X(62)   X(63)    X(64)     Y
# 3919  30.1180   4.7182  111.220  3.2817   5.9076  b'0'
# 901    6.9187   4.8601  102.130  3.5737  84.0930  b'0'
# 2362   8.6524   4.1116  125.640  2.9051   7.9916  b'0'
# 4112  87.5700  14.9730  112.160  3.2542   2.3141  b'0'
# 6059  24.5400   9.1310   38.307  9.5282   7.7023  b'0'
#
# [5 rows x 65 columns]

# %% [markdown]
# ## Understanding the data

# %%
# Get the shape (no of rows & columns) in our dataset

df.shape
# Out:
# (7027, 65)

# %%
# Understanding Data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7027 entries, 0 to 7026
# Data columns (total 65 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X(1)    7024 non-null   float64
#  1   X(2)    7024 non-null   float64
#  2   X(3)    7024 non-null   float64
#  3   X(4)    6997 non-null   float64
#  4   X(5)    7019 non-null   float64
#  5   X(6)    7024 non-null   float64
#  6   X(7)    7024 non-null   float64
#  7   X(8)    7002 non-null   float64
#  8   X(9)    7026 non-null   float64
#  9   X(10)   7024 non-null   float64
#  10  X(11)   6988 non-null   float64
#  11  X(12)   6997 non-null   float64
#  12  X(13)   7027 non-null   float64
#  13  X(14)   7024 non-null   float64
#  14  X(15)   7025 non-null   float64
#  15  X(16)   7002 non-null   float64
#  16  X(17)   7002 non-null   float64
#  17  X(18)   7024 non-null   float64
#  18  X(19)   7027 non-null   float64
#  19  X(20)   7027 non-null   float64
#  20  X(21)   5405 non-null   float64
#  21  X(22)   7024 non-null   float64
#  22  X(23)   7027 non-null   float64
#  23  X(24)   6903 non-null   float64
#  24  X(25)   7024 non-null   float64
#  25  X(26)   7002 non-null   float64
#  26  X(27)   6716 non-null   float64
#  27  X(28)   6993 non-null   float64
#  28  X(29)   7024 non-null   float64
#  29  X(30)   7027 non-null   float64
#  30  X(31)   7027 non-null   float64
#  31  X(32)   6989 non-null   float64
#  32  X(33)   6997 non-null   float64
#  33  X(34)   7002 non-null   float64
#  34  X(35)   7024 non-null   float64
#  35  X(36)   7024 non-null   float64
#  36  X(37)   4287 non-null   float64
#  37  X(38)   7024 non-null   float64
#  38  X(39)   7027 non-null   float64
#  39  X(40)   6997 non-null   float64
#  40  X(41)   6943 non-null   float64
#  41  X(42)   7027 non-null   float64
#  42  X(43)   7027 non-null   float64
#  43  X(44)   7027 non-null   float64
#  44  X(45)   6893 non-null   float64
#  45  X(46)   6996 non-null   float64
#  46  X(47)   6998 non-null   float64
#  47  X(48)   7024 non-null   float64
#  48  X(49)   7027 non-null   float64
#  49  X(50)   7002 non-null   float64
#  50  X(51)   7024 non-null   float64
#  51  X(52)   6998 non-null   float64
#  52  X(53)   6993 non-null   float64
#  53  X(54)   6993 non-null   float64
#  54  X(55)   7027 non-null   float64
#  55  X(56)   7027 non-null   float64
#  56  X(57)   7026 non-null   float64
#  57  X(58)   7027 non-null   float64
#  58  X(59)   7026 non-null   float64
#  59  X(60)   6892 non-null   float64
#  60  X(61)   7005 non-null   float64
#  61  X(62)   7027 non-null   float64
#  62  X(63)   6997 non-null   float64
#  63  X(64)   6993 non-null   float64
#  64  Y       7027 non-null   object
# dtypes: float64(64), object(1)
# memory usage: 3.5+ MB

# %%
df.describe()
# Out:
#               X(1)         X(2)         X(3)         X(4)          X(5)  \
# count  7024.000000  7024.000000  7024.000000  6997.000000  7.019000e+03
# mean      0.034660     0.560215     0.119969     2.629143 -2.631672e+02
# std       4.565504     5.350084     5.275459    13.257356  3.707460e+04
# min    -256.890000   -72.162000  -440.500000     0.000000 -2.722100e+06
# 25%       0.021182     0.296678     0.026968     1.063100 -4.449800e+01
# 50%       0.075802     0.482960     0.181275     1.502000 -5.373900e+00
# 75%       0.160268     0.680233     0.362548     2.460700  3.777050e+01
# max      94.280000   441.500000     1.000000  1017.800000  9.909000e+05
#
#               X(6)         X(7)         X(8)         X(9)        X(10)  ...  \
# count  7024.000000  7024.000000  7002.000000  7026.000000  7024.000000  ...
# mean      0.059712     0.313876     2.623996     5.552855     1.825832  ...
# std       6.051113     8.353274    18.708327   101.995448    33.836452  ...
# min    -397.890000  -189.560000  -141.410000     0.000005  -440.550000  ...
# 25%       0.000000     0.028023     0.445710     1.037225     0.300785  ...
# 50%       0.000000     0.090109     1.015100     1.205750     0.492235  ...
# 75%       0.146660     0.188667     2.267675     2.132975     0.675677  ...
# max     303.670000   453.770000  1452.200000  3876.100000  1099.500000  ...
#
#               X(55)         X(56)        X(57)         X(58)        X(59)  \
# count  7.027000e+03  7.027000e+03  7026.000000  7.027000e+03  7026.000000
# mean   8.855693e+03 -1.577367e+02     0.193243  1.587409e+02     0.277829
# std    7.247527e+04  1.322125e+04     4.344046  1.322124e+04     6.339149
# min   -8.004700e+05 -1.108300e+06  -315.370000 -4.194000e-03  -327.970000
# 25%    9.712000e+01  2.031450e-02     0.056772  8.647650e-01     0.000000
# 50%    1.604800e+03  6.338200e-02     0.175745  9.388100e-01     0.028438
# 75%    5.955900e+03  1.376950e-01     0.351922  9.820150e-01     0.273867
# max    4.398400e+06  1.000000e+00   126.670000  1.108300e+06   119.580000
#
#               X(60)         X(61)         X(62)        X(63)          X(64)
# count  6.892000e+03   7005.000000  7.027000e+03  6997.000000    6993.000000
# mean   4.328830e+02     15.642228  4.763202e+03     8.126852     208.731950
# std    2.612802e+04    261.554534  3.107835e+05    19.996419    5140.708804
# min    4.700000e-05      0.000016  0.000000e+00     0.000015       0.000010
# 25%    5.923950e+00      4.829000  4.322250e+01     3.425400       2.538600
# 50%    1.004050e+01      7.033700  6.850900e+01     5.303200       4.637700
# 75%    2.013900e+01     10.703000  1.063350e+02     8.357900       9.782200
# max    2.137800e+06  21110.000000  2.501600e+07  1042.200000  294770.000000
#
# [8 rows x 64 columns]

# %% [markdown]
# ## Dropping duplicate rows

# %%
df.shape
# Out:
# (7027, 65)

# %%
df.duplicated().sum()
# Out:
# 82

# %%
df.drop_duplicates(inplace = True)

# %%
df.shape
# Out:
# (6945, 65)

# %% [markdown]
# ## Replacing the values of target variable; replacing b'0' by 0 and b'1' by 1.

# %%
df['Y'].value_counts()
# Out:
# b'0'    6674
# b'1'     271
# Name: Y, dtype: int64

# %%
df = pd.get_dummies(df,columns=['Y'],drop_first=True)

# %%
# Renaming target column again to 'Y'
df.rename(columns={"Y_b'1'": 'Y'}, inplace=True)
df
# Out:
#           X(1)     X(2)     X(3)     X(4)      X(5)      X(6)      X(7)  \
# 0     0.200550  0.37951  0.39641  2.04720   32.3510  0.388250  0.249760
# 1     0.209120  0.49988  0.47225  1.94470   14.7860  0.000000  0.258340
# 2     0.248660  0.69592  0.26713  1.55480   -1.1523  0.000000  0.309060
# 3     0.081483  0.30734  0.45879  2.49280   51.9520  0.149880  0.092704
# 4     0.187320  0.61323  0.22960  1.40630   -7.3128  0.187320  0.187320
# ...        ...      ...      ...      ...       ...       ...       ...
# 7022  0.018371  0.47410 -0.13619  0.60839  -18.4490  0.018371  0.018371
# 7023 -0.013359  0.58354 -0.02265  0.92896  -42.2320 -0.013359 -0.015036
# 7024  0.006338  0.50276  0.43923  1.87360    9.7417  0.006338  0.012022
# 7025 -0.041643  0.84810 -0.12852  0.57485 -121.9200  0.000000 -0.036795
# 7026  0.014946  0.94648  0.03211  1.03630  -20.5810  0.000000  0.015260
#
#           X(8)     X(9)     X(10)  ...     X(56)     X(57)    X(58)     X(59)  \
# 0     1.330500  1.13890  0.504940  ...  0.121960  0.397180  0.87804  0.001924
# 1     0.996010  1.69960  0.497880  ...  0.121300  0.420020  0.85300  0.000000
# 2     0.436950  1.30900  0.304080  ...  0.241140  0.817740  0.76599  0.694840
# 3     1.866100  1.05710  0.573530  ...  0.054015  0.142070  0.94598  0.000000
# 4     0.630700  1.15590  0.386770  ...  0.134850  0.484310  0.86515  0.124440
# ...        ...      ...       ...  ...       ...       ...      ...       ...
# 7022  0.972030  1.01210  0.460840  ...  0.011909  0.039866  0.98809  0.274140
# 7023  0.562890  0.98904  0.328470  ... -0.011082 -0.040671  1.01110  0.805920
# 7024  0.983560  1.00830  0.494490  ...  0.008258  0.012817  0.99174  0.000000
# 7025  0.179010  0.42138  0.151820  ... -0.232720 -0.274290  0.98788  3.593100
# 7026  0.056357  2.96940  0.053341  ...  0.015705  0.280210  0.97443  1.179200
#
#         X(60)    X(61)    X(62)    X(63)     X(64)  Y
# 0      8.4160   5.1372   82.658   4.4158   7.42770  0
# 1      4.1486   3.2732  107.350   3.4000  60.98700  0
# 2      4.9909   3.9510  134.270   2.7185   5.20780  0
# 3      4.5746   3.6147   86.435   4.2228   5.54970  0
# 4      6.3985   4.3158  127.210   2.8692   7.89800  0
# ...       ...      ...      ...      ...       ... ..
# 7022  73.5050  79.2370   31.268  11.6730   5.14890  1
# 7023  10.5990   7.1740   94.092   3.8792   1.75720  1
# 7024  10.4700   6.0759   51.019   7.1542  62.00100  1
# 7025  39.7030   3.1420  261.850   1.3939   0.51005  1
# 7026  15.0360   4.1741  108.640   3.3599  35.11800  1
#
# [6945 rows x 65 columns]

# %% [markdown]
# ## Handling missing values

# %%
# Get the no of missing data points per column

df.isnull().sum()
# Out:
# X(1)      3
# X(2)      3
# X(3)      3
# X(4)     29
# X(5)      8
#          ..
# X(61)    21
# X(62)     0
# X(63)    29
# X(64)    34
# Y         0
# Length: 65, dtype: int64

# %%
# Get the percentage of missing data points per column

df.isnull().mean()*100
# Out:
# X(1)     0.043197
# X(2)     0.043197
# X(3)     0.043197
# X(4)     0.417567
# X(5)     0.115191
#            ...
# X(61)    0.302376
# X(62)    0.000000
# X(63)    0.417567
# X(64)    0.489561
# Y        0.000000
# Length: 65, dtype: float64

# %%
# Percentage of data that is missing

total_cells = np.product(df.shape)
missing_values_count = df.isnull().sum()
total_missing = missing_values_count.sum()

percent_missing = (total_missing / total_cells) * 100
print('Percentage of data that is missing in entire dataset :', percent_missing, '% .')
# Out:
# Percentage of data that is missing in entire dataset : 1.2781746691033948 % .

# %%
# Calculate the number of rows and columns for the subplot grid
num_cols = 8
num_features = len(df.columns)
num_rows = (num_features + num_cols - 1) // num_cols  # Ceiling division to ensure all features are included

# Create subplots to display density plots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 20))
fig.suptitle('Distribution of Input Columns before removing missing values', fontsize=16)

# Iterate through each column and create density plots
for i, column in enumerate(df.columns):
    row_num = i // num_cols
    col_num = i % num_cols
    ax = axes[row_num, col_num]
    
    # Plot density plot for the column
    sns.kdeplot(data=df[column], ax=ax, fill=True)
    ax.set_title(column, fontsize=10)
    ax.set_xlabel('Value')
    ax.set_ylabel('Density')

# Adjust layout and spacing of subplots
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# Show the plots
plt.show()

# %%
import pandas as pd
from sklearn.impute import SimpleImputer

def fill_missing_values(dataset):
    Y = None 
    if Y in dataset.columns:
        target = dataset[Y]
        features = dataset.drop(columns=[Y])
    else:
        features = dataset
    
    # Initialize the imputer with median
    imputer = SimpleImputer(strategy='median')
    
    # Fit and transform the features using the imputer
    filled_features = imputer.fit_transform(features)
    
    # Convert the filled features back to a DataFrame
    filled_features_df = pd.DataFrame(filled_features, columns=features.columns)
    
    # Concatenate target variable back
    if Y in dataset.columns:
        filled_features_df[Y] = target
    
    return filled_features_df

df = fill_missing_values(df)

# %%
# Checking again just to make sure that whether data contain missing values or not.

total_cells = np.product(df.shape)
missing_values_count = df.isnull().sum()
total_missing = missing_values_count.sum()

percent_missing = (total_missing / total_cells) * 100
print('Percentage of data that is missing in entire dataset :', percent_missing, '% .')
# Out:
# Percentage of data that is missing in entire dataset : 0.0 % .

# %%
# Number of rows and columns for the subplot grid
num_cols = 8
num_features = len(df.columns)
num_rows = (num_features + num_cols - 1) // num_cols  # Ceiling division to ensure all features are included

# Creating subplots to display density plots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 20))
fig.suptitle('Distribution of Input Columns after removing missing values', fontsize=16)

# Iterating through each column and create density plots
for i, column in enumerate(df.columns):
    row_num = i // num_cols
    col_num = i % num_cols
    ax = axes[row_num, col_num]
    
    # Plot density plot for the column
    sns.kdeplot(data=df[column], ax=ax, fill=True)
    ax.set_title(column, fontsize=10)
    ax.set_xlabel('Value')
    ax.set_ylabel('Density')

# Adjusting layout and spacing of subplots
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

plt.show()

# %% [markdown]
# ## Dealing with Outliers

# %%
# Creating subplots to display box plots
num_cols =  8  
num_features = len(df.columns)
num_rows = (num_features + num_cols - 1) // num_cols  # Ceiling division to ensure all features are included

fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 20))
fig.suptitle('Box Plots - Outliers Detection', fontsize=16)

# Iterating through each column and create box plots
for i, column in enumerate(df.columns):
    row_num = i // num_cols
    col_num = i % num_cols
    ax = axes[row_num, col_num]
    
    # Plot box plot for the column
    ax.boxplot(df[column], vert=False)
    ax.set_title(column, fontsize=10)
    ax.set_xlabel('Value')
    
# Hiding empty subplots
for i in range(num_features, num_cols * num_rows):
    row_num = i // num_cols
    col_num = i % num_cols
    axes[row_num, col_num].axis('off')

# Adjusting layout and spacing of subplots
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# Show the plots
plt.show()

# %%
import pandas as pd

def handle_outliers_iqr(df, target_col='Y', lower_limit=1.5, upper_limit=1.5):
    Q1 = df.quantile(0.25)
    Q3 = df.quantile(0.75)
    IQR = Q3 - Q1

    # Calculate the lower and upper bounds for each column
    lower_bound = Q1 - lower_limit * IQR
    upper_bound = Q3 + upper_limit * IQR

    # Treat the outliers in each column
    for col in df.columns:
        if col != target_col:
            df[col] = df[col].apply(lambda x: lower_bound[col] if x < lower_bound[col] else x)
            df[col] = df[col].apply(lambda x: upper_bound[col] if x > upper_bound[col] else x)

    return df

# Call the function to handle outliers in the DataFrame
df = handle_outliers_iqr(df)

# %%
# Creating subplots to display box plots
num_cols =  8  
num_features = len(df.columns)
num_rows = (num_features + num_cols - 1) // num_cols  # Ceiling division to ensure all features are included

fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 20))
fig.suptitle('Box Plots - Outliers Detection', fontsize=16)

# Iterating through each column and create box plots
for i, column in enumerate(df.columns):
    row_num = i // num_cols
    col_num = i % num_cols
    ax = axes[row_num, col_num]
    
    # Plot box plot for the column
    ax.boxplot(df[column], vert=False)
    ax.set_title(column, fontsize=10)
    ax.set_xlabel('Value')
    
# Hiding empty subplots
for i in range(num_features, num_cols * num_rows):
    row_num = i // num_cols
    col_num = i % num_cols
    axes[row_num, col_num].axis('off')

# Adjusting layout and spacing of subplots
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# Show the plots
plt.show()

# %%
df.to_csv(r'df1.csv', index=False)

# %%
# !pip install jupyterthemes
# Out:
# Collecting jupyterthemes
#   Using cached jupyterthemes-0.20.0-py2.py3-none-any.whl (7.0 MB)
# Requirement already satisfied: jupyter-core in c:\users\xgboost\anaconda3\lib\site-packages (from jupyterthemes) (5.3.0)
# Requirement already satisfied: notebook>=5.6.0 in c:\users\xgboost\anaconda3\lib\site-packages (from jupyterthemes) (6.5.4)
# Requirement already satisfied: ipython>=5.4.1 in c:\users\xgboost\anaconda3\lib\site-packages (from jupyterthemes) (8.12.0)
# Requirement already satisfied: matplotlib>=1.4.3 in c:\users\xgboost\anaconda3\lib\site-packages (from jupyterthemes) (3.7.1)
# Collecting lesscpy>=0.11.2 (from jupyterthemes)
#   Using cached lesscpy-0.15.1-py2.py3-none-any.whl (46 kB)
# Requirement already satisfied: backcall in c:\users\xgboost\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.2.0)
# Requirement already satisfied: decorator in c:\users\xgboost\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\xgboost\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\xgboost\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\xgboost\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\xgboost\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\xgboost\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\xgboost\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\xgboost\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (5.7.1)
# Requirement already satisfied: colorama in c:\users\xgboost\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.4.6)
# Requirement already satisfied: ply in c:\users\xgboost\anaconda3\lib\site-packages (from lesscpy>=0.11.2->jupyterthemes) (3.11)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\xgboost\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\xgboost\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\xgboost\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\xgboost\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\xgboost\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\xgboost\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\xgboost\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\xgboost\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\xgboost\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (2.8.2)
# Requirement already satisfied: jinja2 in c:\users\xgboost\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (3.1.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\xgboost\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (6.3.2)
# Requirement already satisfied: pyzmq>=17 in c:\users\xgboost\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (23.2.0)
# Requirement already satisfied: argon2-cffi in c:\users\xgboost\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (21.3.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\users\xgboost\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (7.4.9)
# Requirement already satisfied: ipython-genutils in c:\users\xgboost\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (0.2.0)
# Requirement already satisfied: nbformat in c:\users\xgboost\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (5.7.0)
# Requirement already satisfied: nbconvert>=5 in c:\users\xgboost\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\xgboost\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (1.5.6)
# Requirement already satisfied: ipykernel in c:\users\xgboost\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (6.19.2)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\xgboost\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\xgboost\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (0.17.1)
# Requirement already satisfied: prometheus-client in c:\users\xgboost\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (0.14.1)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\xgboost\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (0.5.5)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\xgboost\anaconda3\lib\site-packages (from jupyter-core->jupyterthemes) (2.5.2)
# Requirement already satisfied: pywin32>=300 in c:\users\xgboost\anaconda3\lib\site-packages (from jupyter-core->jupyterthemes) (305.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\xgboost\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.4.1->jupyterthemes) (0.8.3)
# Requirement already satisfied: entrypoints in c:\users\xgboost\anaconda3\lib\site-packages (from jupyter-client>=5.3.4->notebook>=5.6.0->jupyterthemes) (0.4)
# Requirement already satisfied: jupyter-server>=1.8 in c:\users\xgboost\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (1.23.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\xgboost\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (0.2.2)
# Requirement already satisfied: lxml in c:\users\xgboost\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\xgboost\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (4.12.2)
# Requirement already satisfied: bleach in c:\users\xgboost\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\xgboost\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\xgboost\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\xgboost\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (2.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\xgboost\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\xgboost\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.5.13)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\xgboost\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\xgboost\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (1.2.1)
# Requirement already satisfied: fastjsonschema in c:\users\xgboost\anaconda3\lib\site-packages (from nbformat->notebook>=5.6.0->jupyterthemes) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\xgboost\anaconda3\lib\site-packages (from nbformat->notebook>=5.6.0->jupyterthemes) (4.17.3)
# Requirement already satisfied: wcwidth in c:\users\xgboost\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=5.4.1->jupyterthemes) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\xgboost\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=1.4.3->jupyterthemes) (1.16.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\xgboost\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=5.6.0->jupyterthemes) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\xgboost\anaconda3\lib\site-packages (from argon2-cffi->notebook>=5.6.0->jupyterthemes) (21.2.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\xgboost\anaconda3\lib\site-packages (from ipykernel->notebook>=5.6.0->jupyterthemes) (0.1.2)
# Requirement already satisfied: debugpy>=1.0 in c:\users\xgboost\anaconda3\lib\site-packages (from ipykernel->notebook>=5.6.0->jupyterthemes) (1.6.7)
# Requirement already satisfied: psutil in c:\users\xgboost\anaconda3\lib\site-packages (from ipykernel->notebook>=5.6.0->jupyterthemes) (5.9.0)
# Requirement already satisfied: executing in c:\users\xgboost\anaconda3\lib\site-packages (from stack-data->ipython>=5.4.1->jupyterthemes) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\xgboost\anaconda3\lib\site-packages (from stack-data->ipython>=5.4.1->jupyterthemes) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\xgboost\anaconda3\lib\site-packages (from stack-data->ipython>=5.4.1->jupyterthemes) (0.2.2)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\xgboost\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\xgboost\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (0.18.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\xgboost\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (3.5.0)
# Requirement already satisfied: websocket-client in c:\users\xgboost\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (0.58.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\xgboost\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=5.6.0->jupyterthemes) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\xgboost\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=5.6.0->jupyterthemes) (2.4)
# Requirement already satisfied: webencodings in c:\users\xgboost\anaconda3\lib\site-packages (from bleach->nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.5.1)
# Requirement already satisfied: idna>=2.8 in c:\users\xgboost\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\xgboost\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\xgboost\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=5.6.0->jupyterthemes) (2.21)
# Installing collected packages: lesscpy, jupyterthemes
# Successfully installed jupyterthemes-0.20.0 lesscpy-0.15.1

# %%
# !jt -l
# Out:
# Available Themes:
#    chesterish
#    grade3
#    gruvboxd
#    gruvboxl
#    monokai
#    oceans16
#    onedork
#    solarizedd
#    solarizedl

# %%
# !jt
