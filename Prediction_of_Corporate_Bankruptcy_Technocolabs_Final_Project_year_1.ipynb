# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/csv_result-1year.csv')

# %%
data.head()
# Out:
#    id     Attr1    Attr2    Attr3   Attr4    Attr5    Attr6     Attr7  \
# 0   1   0.20055  0.37951  0.39641  2.0472   32.351  0.38825   0.24976
# 1   2   0.20912  0.49988  0.47225  1.9447   14.786        0   0.25834
# 2   3   0.24866  0.69592  0.26713  1.5548  -1.1523        0   0.30906
# 3   4  0.081483  0.30734  0.45879  2.4928   51.952  0.14988  0.092704
# 4   5   0.18732  0.61323   0.2296  1.4063  -7.3128  0.18732   0.18732
#
#      Attr8   Attr9  ...    Attr56   Attr57   Attr58    Attr59  Attr60  Attr61  \
# 0   1.3305  1.1389  ...  0.121960  0.39718  0.87804  0.001924   8.416  5.1372
# 1  0.99601  1.6996  ...  0.121300  0.42002  0.85300         0  4.1486  3.2732
# 2  0.43695   1.309  ...  0.241140  0.81774  0.76599   0.69484  4.9909   3.951
# 3   1.8661  1.0571  ...  0.054015  0.14207  0.94598         0  4.5746  3.6147
# 4   0.6307  1.1559  ...  0.134850  0.48431  0.86515   0.12444  6.3985  4.3158
#
#     Attr62  Attr63  Attr64  class
# 0   82.658  4.4158  7.4277      0
# 1  107.350     3.4  60.987      0
# 2  134.270  2.7185  5.2078      0
# 3   86.435  4.2228  5.5497      0
# 4  127.210  2.8692   7.898      0
#
# [5 rows x 66 columns]

# %%
data.tail()
# Out:
#         id      Attr1    Attr2     Attr3    Attr4    Attr5      Attr6  \
# 7022  7023   0.018371   0.4741  -0.13619  0.60839  -18.449   0.018371
# 7023  7024  -0.013359  0.58354  -0.02265  0.92896  -42.232  -0.013359
# 7024  7025   0.006338  0.50276   0.43923   1.8736   9.7417   0.006338
# 7025  7026  -0.041643   0.8481  -0.12852  0.57485  -121.92          0
# 7026  7027   0.014946  0.94648   0.03211   1.0363  -20.581          0
#
#           Attr7     Attr8    Attr9  ...    Attr56     Attr57   Attr58  \
# 7022   0.018371   0.97203   1.0121  ...  0.011909   0.039866  0.98809
# 7023  -0.015036   0.56289  0.98904  ... -0.011082  -0.040671  1.01110
# 7024   0.012022   0.98356   1.0083  ...  0.008258   0.012817  0.99174
# 7025  -0.036795   0.17901  0.42138  ... -0.232720   -0.27429  0.98788
# 7026    0.01526  0.056357   2.9694  ...  0.015705    0.28021  0.97443
#
#        Attr59  Attr60  Attr61   Attr62  Attr63   Attr64  class
# 7022  0.27414  73.505  79.237   31.268  11.673   5.1489      1
# 7023  0.80592  10.599   7.174   94.092  3.8792   1.7572      1
# 7024        0   10.47  6.0759   51.019  7.1542   62.001      1
# 7025   3.5931  39.703   3.142  261.850  1.3939  0.51005      1
# 7026   1.1792  15.036  4.1741  108.640  3.3599   35.118      1
#
# [5 rows x 66 columns]

# %%
data
# Out:
#         id      Attr1    Attr2     Attr3    Attr4    Attr5      Attr6  \
# 0        1    0.20055  0.37951   0.39641   2.0472   32.351    0.38825
# 1        2    0.20912  0.49988   0.47225   1.9447   14.786          0
# 2        3    0.24866  0.69592   0.26713   1.5548  -1.1523          0
# 3        4   0.081483  0.30734   0.45879   2.4928   51.952    0.14988
# 4        5    0.18732  0.61323    0.2296   1.4063  -7.3128    0.18732
# ...    ...        ...      ...       ...      ...      ...        ...
# 7022  7023   0.018371   0.4741  -0.13619  0.60839  -18.449   0.018371
# 7023  7024  -0.013359  0.58354  -0.02265  0.92896  -42.232  -0.013359
# 7024  7025   0.006338  0.50276   0.43923   1.8736   9.7417   0.006338
# 7025  7026  -0.041643   0.8481  -0.12852  0.57485  -121.92          0
# 7026  7027   0.014946  0.94648   0.03211   1.0363  -20.581          0
#
#           Attr7     Attr8    Attr9  ...    Attr56     Attr57   Attr58  \
# 0       0.24976    1.3305   1.1389  ...  0.121960    0.39718  0.87804
# 1       0.25834   0.99601   1.6996  ...  0.121300    0.42002  0.85300
# 2       0.30906   0.43695    1.309  ...  0.241140    0.81774  0.76599
# 3      0.092704    1.8661   1.0571  ...  0.054015    0.14207  0.94598
# 4       0.18732    0.6307   1.1559  ...  0.134850    0.48431  0.86515
# ...         ...       ...      ...  ...       ...        ...      ...
# 7022   0.018371   0.97203   1.0121  ...  0.011909   0.039866  0.98809
# 7023  -0.015036   0.56289  0.98904  ... -0.011082  -0.040671  1.01110
# 7024   0.012022   0.98356   1.0083  ...  0.008258   0.012817  0.99174
# 7025  -0.036795   0.17901  0.42138  ... -0.232720   -0.27429  0.98788
# 7026    0.01526  0.056357   2.9694  ...  0.015705    0.28021  0.97443
#
#         Attr59  Attr60  Attr61   Attr62  Attr63   Attr64  class
# 0     0.001924   8.416  5.1372   82.658  4.4158   7.4277      0
# 1            0  4.1486  3.2732  107.350     3.4   60.987      0
# 2      0.69484  4.9909   3.951  134.270  2.7185   5.2078      0
# 3            0  4.5746  3.6147   86.435  4.2228   5.5497      0
# 4      0.12444  6.3985  4.3158  127.210  2.8692    7.898      0
# ...        ...     ...     ...      ...     ...      ...    ...
# 7022   0.27414  73.505  79.237   31.268  11.673   5.1489      1
# 7023   0.80592  10.599   7.174   94.092  3.8792   1.7572      1
# 7024         0   10.47  6.0759   51.019  7.1542   62.001      1
# 7025    3.5931  39.703   3.142  261.850  1.3939  0.51005      1
# 7026    1.1792  15.036  4.1741  108.640  3.3599   35.118      1
#
# [7027 rows x 66 columns]

# %%
data_keys= list(data.keys())
len(data_keys)
# Out:
# 66

# %%
print(data.shape)
# Out:
# (7027, 66)

# %%
data.describe()
# Out:
#                 id        Attr13       Attr19        Attr20       Attr23  \
# count  7027.000000   7027.000000  7027.000000  7.027000e+03  7027.000000
# mean   3514.000000      2.093345     0.462392  1.162128e+03     0.423610
# std    2028.664503    159.699448    30.646874  9.315822e+04    29.742101
# min       1.000000   -607.420000  -622.060000  0.000000e+00  -634.590000
# 25%    1757.500000      0.038073     0.014812  1.708300e+01     0.011253
# 50%    3514.000000      0.080830     0.049966  3.561200e+01     0.042097
# 75%    5270.500000      0.144955     0.104500  6.070100e+01     0.088314
# max    7027.000000  13315.000000  2156.800000  7.809200e+06  2156.800000
#
#               Attr30       Attr31       Attr39       Attr42        Attr43  \
# count    7027.000000  7027.000000  7027.000000  7027.000000  7.027000e+03
# mean       23.568949     0.473717     0.269342     0.263638  4.588504e+03
# std      1826.847970    30.647711    27.064231    27.071123  3.627309e+05
# min      -149.070000  -622.060000  -701.630000  -701.630000  0.000000e+00
# 25%         0.094681     0.019233     0.012786     0.011540  6.525600e+01
# 50%         0.207130     0.056637     0.046948     0.047783  9.461200e+01
# 75%         0.365635     0.114970     0.103375     0.102165  1.304150e+02
# max    152860.000000  2156.800000  2156.500000  2156.800000  3.039300e+07
#
#              Attr44       Attr49        Attr55        Attr56        Attr58  \
# count  7.027000e+03  7027.000000  7.027000e+03  7.027000e+03  7.027000e+03
# mean   3.426404e+03    -1.367363  8.855693e+03 -1.577367e+02  1.587409e+02
# std    2.696211e+05   107.717867  7.247527e+04  1.322125e+04  1.322124e+04
# min    0.000000e+00 -9001.000000 -8.004700e+05 -1.108300e+06 -4.194000e-03
# 25%    3.387300e+01    -0.009992  9.712000e+01  2.031450e-02  8.647650e-01
# 50%    5.180000e+01     0.022759  1.604800e+03  6.338200e-02  9.388100e-01
# 75%    7.550250e+01     0.075464  5.955900e+03  1.376950e-01  9.820150e-01
# max    2.258400e+07    31.639000  4.398400e+06  1.000000e+00  1.108300e+06
#
#              Attr62        class
# count  7.027000e+03  7027.000000
# mean   4.763202e+03     0.038566
# std    3.107835e+05     0.192571
# min    0.000000e+00     0.000000
# 25%    4.322250e+01     0.000000
# 50%    6.850900e+01     0.000000
# 75%    1.063350e+02     0.000000
# max    2.501600e+07     1.000000

# %%
data.describe().transpose()
# Out:
#          count         mean            std           min          25%  \
# id      7027.0  3514.000000    2028.664503  1.000000e+00  1757.500000
# Attr13  7027.0     2.093345     159.699448 -6.074200e+02     0.038073
# Attr19  7027.0     0.462392      30.646874 -6.220600e+02     0.014812
# Attr20  7027.0  1162.127976   93158.220665  0.000000e+00    17.083000
# Attr23  7027.0     0.423610      29.742101 -6.345900e+02     0.011253
# Attr30  7027.0    23.568949    1826.847970 -1.490700e+02     0.094681
# Attr31  7027.0     0.473717      30.647711 -6.220600e+02     0.019233
# Attr39  7027.0     0.269342      27.064231 -7.016300e+02     0.012786
# Attr42  7027.0     0.263638      27.071123 -7.016300e+02     0.011540
# Attr43  7027.0  4588.503542  362730.934024  0.000000e+00    65.256000
# Attr44  7027.0  3426.404199  269621.104411  0.000000e+00    33.873000
# Attr49  7027.0    -1.367363     107.717867 -9.001000e+03    -0.009992
# Attr55  7027.0  8855.693294   72475.270699 -8.004700e+05    97.120000
# Attr56  7027.0  -157.736739   13221.247567 -1.108300e+06     0.020314
# Attr58  7027.0   158.740862   13221.235589 -4.194000e-03     0.864765
# Attr62  7027.0  4763.201955  310783.483587  0.000000e+00    43.222500
# class   7027.0     0.038566       0.192571  0.000000e+00     0.000000
#
#                 50%          75%           max
# id      3514.000000  5270.500000  7.027000e+03
# Attr13     0.080830     0.144955  1.331500e+04
# Attr19     0.049966     0.104500  2.156800e+03
# Attr20    35.612000    60.701000  7.809200e+06
# Attr23     0.042097     0.088314  2.156800e+03
# Attr30     0.207130     0.365635  1.528600e+05
# Attr31     0.056637     0.114970  2.156800e+03
# Attr39     0.046948     0.103375  2.156500e+03
# Attr42     0.047783     0.102165  2.156800e+03
# Attr43    94.612000   130.415000  3.039300e+07
# Attr44    51.800000    75.502500  2.258400e+07
# Attr49     0.022759     0.075464  3.163900e+01
# Attr55  1604.800000  5955.900000  4.398400e+06
# Attr56     0.063382     0.137695  1.000000e+00
# Attr58     0.938810     0.982015  1.108300e+06
# Attr62    68.509000   106.335000  2.501600e+07
# class      0.000000     0.000000  1.000000e+00

# %%
data.corr()
# Out:
# <ipython-input-10-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#               id    Attr13    Attr19    Attr20    Attr23    Attr30    Attr31  \
# id      1.000000  0.005922  0.000239  0.007056  0.001417  0.006414  0.000122
# Attr13  0.005922  1.000000  0.891355  0.994441  0.912277  0.990439  0.891330
# Attr19  0.000239  0.891355  1.000000  0.838674  0.998123  0.825454  0.999987
# Attr20  0.007056  0.994441  0.838674  1.000000  0.864187  0.998352  0.838647
# Attr23  0.001417  0.912277  0.998123  0.864187  1.000000  0.849970  0.998111
# Attr30  0.006414  0.990439  0.825454  0.998352  0.849970  1.000000  0.825427
# Attr31  0.000122  0.891330  0.999987  0.838647  0.998111  0.825427  1.000000
# Attr39  0.009787  0.959589  0.873604  0.949538  0.901708  0.930162  0.873577
# Attr42  0.010050  0.958001  0.865800  0.949431  0.894761  0.929988  0.865771
# Attr43  0.006771  0.992787  0.831874  0.999633  0.857027  0.999528  0.831847
# Attr44  0.006671  0.992046  0.829383  0.999336  0.854406  0.999764  0.829356
# Attr49 -0.006187 -0.988168 -0.819365 -0.997067 -0.843638 -0.999782 -0.819339
# Attr55 -0.016793 -0.000774  0.002328 -0.001487  0.002503 -0.002442  0.002327
# Attr56 -0.007098 -0.994566 -0.839320 -0.999996 -0.864865 -0.998201 -0.839293
# Attr58  0.007099  0.994566  0.839320  0.999996  0.864865  0.998201  0.839293
# Attr62  0.003803  0.942309  0.738362  0.961081  0.759430  0.975288  0.738337
# class   0.333519 -0.002862 -0.004445 -0.002395 -0.004350 -0.002392 -0.004414
#
#           Attr39    Attr42    Attr43    Attr44    Attr49    Attr55    Attr56  \
# id      0.009787  0.010050  0.006771  0.006671 -0.006187 -0.016793 -0.007098
# Attr13  0.959589  0.958001  0.992787  0.992046 -0.988168 -0.000774 -0.994566
# Attr19  0.873604  0.865800  0.831874  0.829383 -0.819365  0.002328 -0.839320
# Attr20  0.949538  0.949431  0.999633  0.999336 -0.997067 -0.001487 -0.999996
# Attr23  0.901708  0.894761  0.857027  0.854406 -0.843638  0.002503 -0.864865
# Attr30  0.930162  0.929988  0.999528  0.999764 -0.999782 -0.002442 -0.998201
# Attr31  0.873577  0.865771  0.831847  0.829356 -0.819339  0.002327 -0.839293
# Attr39  1.000000  0.999870  0.940748  0.937550 -0.922785  0.003554 -0.950356
# Attr42  0.999870  1.000000  0.940639  0.937441 -0.922619  0.003585 -0.950249
# Attr43  0.940748  0.940639  1.000000  0.999956 -0.998759 -0.001874 -0.999559
# Attr44  0.937550  0.937441  0.999956  1.000000 -0.999173 -0.002007 -0.999238
# Attr49 -0.922785 -0.922619 -0.998759 -0.999173  1.000000  0.002710  0.996864
# Attr55  0.003554  0.003585 -0.001874 -0.002007  0.002710  1.000000  0.001454
# Attr56 -0.950356 -0.950249 -0.999559 -0.999238  0.996864  0.001454  1.000000
# Attr58  0.950356  0.950249  0.999559  0.999238 -0.996864 -0.001455 -1.000000
# Attr62  0.826316  0.826233  0.968191  0.970483 -0.979281 -0.005743 -0.960360
# class  -0.001853 -0.001840 -0.002470 -0.002495  0.002517 -0.022040  0.002390
#
#           Attr58    Attr62     class
# id      0.007099  0.003803  0.333519
# Attr13  0.994566  0.942309 -0.002862
# Attr19  0.839320  0.738362 -0.004445
# Attr20  0.999996  0.961081 -0.002395
# Attr23  0.864865  0.759430 -0.004350
# Attr30  0.998201  0.975288 -0.002392
# Attr31  0.839293  0.738337 -0.004414
# Attr39  0.950356  0.826316 -0.001853
# Attr42  0.950249  0.826233 -0.001840
# Attr43  0.999559  0.968191 -0.002470
# Attr44  0.999238  0.970483 -0.002495
# Attr49 -0.996864 -0.979281  0.002517
# Attr55 -0.001455 -0.005743 -0.022040
# Attr56 -1.000000 -0.960360  0.002390
# Attr58  1.000000  0.960360 -0.002389
# Attr62  0.960360  1.000000 -0.002679
# class  -0.002389 -0.002679  1.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7027 entries, 0 to 7026
# Data columns (total 66 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      7027 non-null   int64
#  1   Attr1   7027 non-null   object
#  2   Attr2   7027 non-null   object
#  3   Attr3   7027 non-null   object
#  4   Attr4   7027 non-null   object
#  5   Attr5   7027 non-null   object
#  6   Attr6   7027 non-null   object
#  7   Attr7   7027 non-null   object
#  8   Attr8   7027 non-null   object
#  9   Attr9   7027 non-null   object
#  10  Attr10  7027 non-null   object
#  11  Attr11  7027 non-null   object
#  12  Attr12  7027 non-null   object
#  13  Attr13  7027 non-null   float64
#  14  Attr14  7027 non-null   object
#  15  Attr15  7027 non-null   object
#  16  Attr16  7027 non-null   object
#  17  Attr17  7027 non-null   object
#  18  Attr18  7027 non-null   object
#  19  Attr19  7027 non-null   float64
#  20  Attr20  7027 non-null   float64
#  21  Attr21  7027 non-null   object
#  22  Attr22  7027 non-null   object
#  23  Attr23  7027 non-null   float64
#  24  Attr24  7027 non-null   object
#  25  Attr25  7027 non-null   object
#  26  Attr26  7027 non-null   object
#  27  Attr27  7027 non-null   object
#  28  Attr28  7027 non-null   object
#  29  Attr29  7027 non-null   object
#  30  Attr30  7027 non-null   float64
#  31  Attr31  7027 non-null   float64
#  32  Attr32  7027 non-null   object
#  33  Attr33  7027 non-null   object
#  34  Attr34  7027 non-null   object
#  35  Attr35  7027 non-null   object
#  36  Attr36  7027 non-null   object
#  37  Attr37  7027 non-null   object
#  38  Attr38  7027 non-null   object
#  39  Attr39  7027 non-null   float64
#  40  Attr40  7027 non-null   object
#  41  Attr41  7027 non-null   object
#  42  Attr42  7027 non-null   float64
#  43  Attr43  7027 non-null   float64
#  44  Attr44  7027 non-null   float64
#  45  Attr45  7027 non-null   object
#  46  Attr46  7027 non-null   object
#  47  Attr47  7027 non-null   object
#  48  Attr48  7027 non-null   object
#  49  Attr49  7027 non-null   float64
#  50  Attr50  7027 non-null   object
#  51  Attr51  7027 non-null   object
#  52  Attr52  7027 non-null   object
#  53  Attr53  7027 non-null   object
#  54  Attr54  7027 non-null   object
#  55  Attr55  7027 non-null   float64
#  56  Attr56  7027 non-null   float64
#  57  Attr57  7027 non-null   object
#  58  Attr58  7027 non-null   float64
#  59  Attr59  7027 non-null   object
#  60  Attr60  7027 non-null   object
#  61  Attr61  7027 non-null   object
#  62  Attr62  7027 non-null   float64
#  63  Attr63  7027 non-null   object
#  64  Attr64  7027 non-null   object
#  65  class   7027 non-null   int64
# dtypes: float64(15), int64(2), object(49)
# memory usage: 3.5+ MB

# %%
data.columns
# Out:
# Index(['id', 'Attr1', 'Attr2', 'Attr3', 'Attr4', 'Attr5', 'Attr6', 'Attr7',
#        'Attr8', 'Attr9', 'Attr10', 'Attr11', 'Attr12', 'Attr13', 'Attr14',
#        'Attr15', 'Attr16', 'Attr17', 'Attr18', 'Attr19', 'Attr20', 'Attr21',
#        'Attr22', 'Attr23', 'Attr24', 'Attr25', 'Attr26', 'Attr27', 'Attr28',
#        'Attr29', 'Attr30', 'Attr31', 'Attr32', 'Attr33', 'Attr34', 'Attr35',
#        'Attr36', 'Attr37', 'Attr38', 'Attr39', 'Attr40', 'Attr41', 'Attr42',
#        'Attr43', 'Attr44', 'Attr45', 'Attr46', 'Attr47', 'Attr48', 'Attr49',
#        'Attr50', 'Attr51', 'Attr52', 'Attr53', 'Attr54', 'Attr55', 'Attr56',
#        'Attr57', 'Attr58', 'Attr59', 'Attr60', 'Attr61', 'Attr62', 'Attr63',
#        'Attr64', 'class'],
#       dtype='object')

# %%
data['class'].value_counts()
# Out:
# 0    6756
# 1     271
# Name: class, dtype: int64

# %%
data.isna().sum()
# Out:
# id        0
# Attr1     0
# Attr2     0
# Attr3     0
# Attr4     0
#          ..
# Attr61    0
# Attr62    0
# Attr63    0
# Attr64    0
# class     0
# Length: 66, dtype: int64

# %%
data.hist( figsize=(18,18))
# Out:
# array([[<Axes: title={'center': 'id'}>,
#         <Axes: title={'center': 'Attr13'}>,
#         <Axes: title={'center': 'Attr19'}>,
#         <Axes: title={'center': 'Attr20'}>],
#        [<Axes: title={'center': 'Attr23'}>,
#         <Axes: title={'center': 'Attr30'}>,
#         <Axes: title={'center': 'Attr31'}>,
#         <Axes: title={'center': 'Attr39'}>],
#        [<Axes: title={'center': 'Attr42'}>,
#         <Axes: title={'center': 'Attr43'}>,
#         <Axes: title={'center': 'Attr44'}>,
#         <Axes: title={'center': 'Attr49'}>],
#        [<Axes: title={'center': 'Attr55'}>,
#         <Axes: title={'center': 'Attr56'}>,
#         <Axes: title={'center': 'Attr58'}>,
#         <Axes: title={'center': 'Attr62'}>],
#        [<Axes: title={'center': 'class'}>, <Axes: >, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
# Import label encoder
from sklearn import preprocessing

# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()

# Encode labels in column 'species'.
data['class']= label_encoder.fit_transform(data['class'])

data['class'].unique()
# Out:
# array([0, 1])

# %%
data['class'].value_counts() #verify => SAME AS BEFORE
# Out:
# 0    6756
# 1     271
# Name: class, dtype: int64

# %% [markdown]
# EDA

# %%
total_cells= np.product(data.shape)
total_missing=data.isnull().sum().sum()

# %%
# percent of data that is missing
percent_missing = (total_missing/total_cells) * 100
print(percent_missing)
# Out:
# 0.0

# %%
import missingno as msno
msno.matrix(data)
# Out:
# <Axes: >

# %%
fig, axe = plt.subplots(figsize=(30,20))
msno.heatmap(data,ax=axe)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/matrix.py:309: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# /usr/local/lib/python3.10/dist-packages/seaborn/matrix.py:309: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# <Axes: >

# %%
plt.figure(figsize=(50,60))
pltmv=sns.displot(data=data.isna().melt(value_name="missing"),
            y="variable",hue="missing",
            multiple="fill",height=10,aspect=1)
plt.savefig("visualizing_missing_data_with_barplot.png", dpi=100)

# %% [markdown]
# METHOD 1 MICE MULTIPLE ITERATIVE IMPUTATION -MISSING VALUE

# %%
d1= data.copy()

# %%
from sklearn.impute import KNNImputer

# Replace '?' with NaN in the DataFrame
d1.replace('?', np.nan, inplace=True)

# Assuming 'data_keys' contains the list of column names you want to impute
for i in data_keys:
    X = np.array(d1[i]).reshape(-1, 1)

    # Convert the column to float (including NaNs) before imputing
    X = X.astype(float)

    imputer = KNNImputer(n_neighbors=3)
    X_prep = imputer.fit_transform(X)

    # Assign the imputed values back to the DataFrame
    d1[i] = X_prep.reshape(1, -1)[0]

d1.head()
# Out:
#     id     Attr1    Attr2    Attr3   Attr4    Attr5    Attr6     Attr7  \
# 0  1.0  0.200550  0.37951  0.39641  2.0472  32.3510  0.38825  0.249760
# 1  2.0  0.209120  0.49988  0.47225  1.9447  14.7860  0.00000  0.258340
# 2  3.0  0.248660  0.69592  0.26713  1.5548  -1.1523  0.00000  0.309060
# 3  4.0  0.081483  0.30734  0.45879  2.4928  51.9520  0.14988  0.092704
# 4  5.0  0.187320  0.61323  0.22960  1.4063  -7.3128  0.18732  0.187320
#
#      Attr8   Attr9  ...    Attr56   Attr57   Attr58    Attr59  Attr60  Attr61  \
# 0  1.33050  1.1389  ...  0.121960  0.39718  0.87804  0.001924  8.4160  5.1372
# 1  0.99601  1.6996  ...  0.121300  0.42002  0.85300  0.000000  4.1486  3.2732
# 2  0.43695  1.3090  ...  0.241140  0.81774  0.76599  0.694840  4.9909  3.9510
# 3  1.86610  1.0571  ...  0.054015  0.14207  0.94598  0.000000  4.5746  3.6147
# 4  0.63070  1.1559  ...  0.134850  0.48431  0.86515  0.124440  6.3985  4.3158
#
#     Attr62  Attr63   Attr64  class
# 0   82.658  4.4158   7.4277    0.0
# 1  107.350  3.4000  60.9870    0.0
# 2  134.270  2.7185   5.2078    0.0
# 3   86.435  4.2228   5.5497    0.0
# 4  127.210  2.8692   7.8980    0.0
#
# [5 rows x 66 columns]

# %%
total_cells= np.product(d1.shape)
total_missing=d1.isnull().sum().sum()
# percent of data that is missing
percent_missing = (total_missing/total_cells) * 100
print(percent_missing)
# Out:
# 0.0

# %%
d1.describe()
# Out:
#                 id        Attr1        Attr2        Attr3        Attr4  \
# count  7027.000000  7027.000000  7027.000000  7027.000000  7027.000000
# mean   3514.000000     0.034660     0.560215     0.119969     2.629143
# std    2028.664503     4.564529     5.348941     5.274332    13.229022
# min       1.000000  -256.890000   -72.162000  -440.500000     0.000000
# 25%    1757.500000     0.021208     0.296760     0.027011     1.064100
# 50%    3514.000000     0.075790     0.483090     0.181180     1.505200
# 75%    5270.500000     0.160240     0.680170     0.362500     2.476050
# max    7027.000000    94.280000   441.500000     1.000000  1017.800000
#
#               Attr5        Attr6        Attr7        Attr8        Attr9  ...  \
# count  7.027000e+03  7027.000000  7027.000000  7027.000000  7027.000000  ...
# mean  -2.631672e+02     0.059712     0.313876     2.623996     5.552855  ...
# std    3.705348e+04     6.049821     8.351490    18.675013   101.988190  ...
# min   -2.722100e+06  -397.890000  -189.560000  -141.410000     0.000005  ...
# 25%   -4.462850e+01     0.000000     0.028037     0.447340     1.037250  ...
# 50%   -5.575300e+00     0.000000     0.090177     1.022100     1.206000  ...
# 75%    3.769500e+01     0.146570     0.188880     2.286700     2.133150  ...
# max    9.909000e+05   303.670000   453.770000  1452.200000  3876.100000  ...
#
#              Attr56       Attr57        Attr58       Attr59        Attr60  \
# count  7.027000e+03  7027.000000  7.027000e+03  7027.000000  7.027000e+03
# mean  -1.577367e+02     0.193243  1.587409e+02     0.277829  4.328830e+02
# std    1.322125e+04     4.343737  1.322124e+04     6.338698  2.587579e+04
# min   -1.108300e+06  -315.370000 -4.194000e-03  -327.970000  4.700000e-05
# 25%    2.031450e-02     0.056814  8.647650e-01     0.000000  6.013050e+00
# 50%    6.338200e-02     0.175820  9.388100e-01     0.028451  1.024900e+01
# 75%    1.376950e-01     0.351895  9.820150e-01     0.274140  2.136650e+01
# max    1.000000e+00   126.670000  1.108300e+06   119.580000  2.137800e+06
#
#              Attr61        Attr62       Attr63         Attr64        class
# count   7027.000000  7.027000e+03  7027.000000    7027.000000  7027.000000
# mean      15.642228  4.763202e+03     8.126852     208.731950     0.038566
# std      261.144719  3.107835e+05    19.953682    5128.255341     0.192571
# min        0.000016  0.000000e+00     0.000015       0.000010     0.000000
# 25%        4.834250  4.322250e+01     3.432500       2.550300     0.000000
# 50%        7.046300  6.850900e+01     5.327800       4.657400     0.000000
# 75%       10.775500  1.063350e+02     8.326800       9.912750     0.000000
# max    21110.000000  2.501600e+07  1042.200000  294770.000000     1.000000
#
# [8 rows x 66 columns]

# %%
#!pip install impyute
#from impyute.imputation.cs import mice
#d2=df.copy()
# start the MICE training
#imputed_training=mice(d2.values.astype(float))

# %%
sns.countplot(x=d1['class'])
plt.title('Target feature - Bankrupt class')
# Out:
# Text(0.5, 1.0, 'Target feature - Bankrupt class')

# %% [markdown]
# There is imbalance in the Target value, we need to oversample it based

# %% [markdown]
# OverSamppling :SMOTE

# %%
from imblearn.over_sampling import SMOTE

# %%
X=d1.drop(labels=['class'], axis=1)
y=d1['class']

# %%
oversample = SMOTE()
X,y=oversample.fit_resample(X,y)

# %%
sns.countplot(x=y)
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
data_x= pd.DataFrame(X,columns=data_keys[:len(data_keys)-1])
print(data_x.head())
#y class data
data_x.shape
# Out:
#     id     Attr1    Attr2    Attr3   Attr4    Attr5    Attr6     Attr7  \
# 0  1.0  0.200550  0.37951  0.39641  2.0472  32.3510  0.38825  0.249760
# 1  2.0  0.209120  0.49988  0.47225  1.9447  14.7860  0.00000  0.258340
# 2  3.0  0.248660  0.69592  0.26713  1.5548  -1.1523  0.00000  0.309060
# 3  4.0  0.081483  0.30734  0.45879  2.4928  51.9520  0.14988  0.092704
# 4  5.0  0.187320  0.61323  0.22960  1.4063  -7.3128  0.18732  0.187320
#
#      Attr8   Attr9  ...    Attr55    Attr56   Attr57   Attr58    Attr59  \
# 0  1.33050  1.1389  ...  348690.0  0.121960  0.39718  0.87804  0.001924
# 1  0.99601  1.6996  ...    2304.6  0.121300  0.42002  0.85300  0.000000
# 2  0.43695  1.3090  ...    6332.7  0.241140  0.81774  0.76599  0.694840
# 3  1.86610  1.0571  ...   20545.0  0.054015  0.14207  0.94598  0.000000
# 4  0.63070  1.1559  ...    3186.6  0.134850  0.48431  0.86515  0.124440
#
#    Attr60  Attr61   Attr62  Attr63   Attr64
# 0  8.4160  5.1372   82.658  4.4158   7.4277
# 1  4.1486  3.2732  107.350  3.4000  60.9870
# 2  4.9909  3.9510  134.270  2.7185   5.2078
# 3  4.5746  3.6147   86.435  4.2228   5.5497
# 4  6.3985  4.3158  127.210  2.8692   7.8980
#
# [5 rows x 65 columns]
# (13512, 65)

# %%
data.head()
# Out:
#    id     Attr1    Attr2    Attr3   Attr4    Attr5    Attr6     Attr7  \
# 0   1   0.20055  0.37951  0.39641  2.0472   32.351  0.38825   0.24976
# 1   2   0.20912  0.49988  0.47225  1.9447   14.786        0   0.25834
# 2   3   0.24866  0.69592  0.26713  1.5548  -1.1523        0   0.30906
# 3   4  0.081483  0.30734  0.45879  2.4928   51.952  0.14988  0.092704
# 4   5   0.18732  0.61323   0.2296  1.4063  -7.3128  0.18732   0.18732
#
#      Attr8   Attr9  ...    Attr56   Attr57   Attr58    Attr59  Attr60  Attr61  \
# 0   1.3305  1.1389  ...  0.121960  0.39718  0.87804  0.001924   8.416  5.1372
# 1  0.99601  1.6996  ...  0.121300  0.42002  0.85300         0  4.1486  3.2732
# 2  0.43695   1.309  ...  0.241140  0.81774  0.76599   0.69484  4.9909   3.951
# 3   1.8661  1.0571  ...  0.054015  0.14207  0.94598         0  4.5746  3.6147
# 4   0.6307  1.1559  ...  0.134850  0.48431  0.86515   0.12444  6.3985  4.3158
#
#     Attr62  Attr63  Attr64  class
# 0   82.658  4.4158  7.4277      0
# 1  107.350     3.4  60.987      0
# 2  134.270  2.7185  5.2078      0
# 3   86.435  4.2228  5.5497      0
# 4  127.210  2.8692   7.898      0
#
# [5 rows x 66 columns]
