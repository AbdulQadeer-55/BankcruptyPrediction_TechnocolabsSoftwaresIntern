# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/content/drive/MyDrive/csv_result-5year.csv')

# %%
data
# Out:
#         id      Attr1    Attr2      Attr3    Attr4    Attr5      Attr6  \
# 0        1   0.088238  0.55472    0.01134   1.0205   -66.52    0.34204
# 1        2  -0.006202  0.48465    0.23298   1.5998   6.1825          0
# 2        3    0.13024  0.22142    0.57751   3.6082   120.04    0.18764
# 3        4  -0.089951    0.887    0.26927   1.5222  -55.992  -0.073957
# 4        5   0.048179  0.55041    0.10765   1.2437  -22.959          0
# ...    ...        ...      ...        ...      ...      ...        ...
# 5905  5906   0.012898  0.70621   0.038857   1.1722  -18.907          0
# 5906  5907   -0.57805  0.96702   -0.80085  0.16576  -67.365   -0.57805
# 5907  5908   -0.17905   1.2553   -0.27599  0.74554  -120.44   -0.17905
# 5908  5909   -0.10886  0.74394   0.015449   1.0878  -17.003   -0.10886
# 5909  5910   -0.10537  0.53629  -0.045578  0.91478  -56.068   -0.10537
#
#           Attr7     Attr8    Attr9  ...    Attr56     Attr57   Attr58  \
# 0       0.10949   0.57752   1.0881  ...  0.080955    0.27543  0.91905
# 1     -0.006202    1.0634   1.2757  ... -0.028591  -0.012035  1.00470
# 2       0.16212     3.059   1.1415  ...  0.123960    0.19229  0.87604
# 3     -0.089951    0.1274   1.2754  ...  0.418840   -0.79602  0.59074
# 4       0.05928   0.81682    1.515  ...  0.240400    0.10716  0.77048
# ...         ...       ...      ...  ...       ...        ...      ...
# 5905   0.013981     0.416   1.6768  ...  0.020169   0.043904  1.01220
# 5906   -0.57805  -0.40334  0.93979  ... -0.064073      1.482  1.06410
# 5907   -0.15493  -0.26018   1.1749  ...  0.148880    0.54824  0.85112
# 5908   -0.10918   0.12531  0.84516  ... -0.183200    -1.1677  1.18320
# 5909   -0.10994    0.8646   0.9504  ... -0.052186   -0.22725  1.05220
#
#          Attr59  Attr60  Attr61   Attr62  Attr63   Attr64  class
# 0      0.002024  7.2711  4.7343  142.760  2.5568   3.2597      0
# 1       0.15222  6.0911  3.2749  111.140  3.2841     3.37      0
# 2             0  8.7934   2.987   71.531  5.1027   5.6188      0
# 3        2.8787  7.6524  3.3302  147.560  2.4735   5.9299      0
# 4       0.13938  10.118   4.095  106.430  3.4294   3.3622      0
# ...         ...     ...     ...      ...     ...      ...    ...
# 5905     1.2594  13.472  12.432   49.117  7.4313   2.2799      1
# 5906  -0.018084  110.72  44.759   81.220   4.494   5.1305      1
# 5907   -0.52243  9.8526  3.4892  207.870  1.7559   9.9527      1
# 5908     6.0924  13.886  6.0769   83.122  4.3911  0.95575      1
# 5909   0.003196  7.7332  4.7174  136.850  2.6672   2.7927      1
#
# [5910 rows x 66 columns]

# %%
data.head()
# Out:
#    id      Attr1    Attr2    Attr3   Attr4    Attr5      Attr6      Attr7  \
# 0   1   0.088238  0.55472  0.01134  1.0205   -66.52    0.34204    0.10949
# 1   2  -0.006202  0.48465  0.23298  1.5998   6.1825          0  -0.006202
# 2   3    0.13024  0.22142  0.57751  3.6082   120.04    0.18764    0.16212
# 3   4  -0.089951    0.887  0.26927  1.5222  -55.992  -0.073957  -0.089951
# 4   5   0.048179  0.55041  0.10765  1.2437  -22.959          0    0.05928
#
#      Attr8   Attr9  ...    Attr56     Attr57   Attr58    Attr59  Attr60  \
# 0  0.57752  1.0881  ...  0.080955    0.27543  0.91905  0.002024  7.2711
# 1   1.0634  1.2757  ... -0.028591  -0.012035  1.00470   0.15222  6.0911
# 2    3.059  1.1415  ...  0.123960    0.19229  0.87604         0  8.7934
# 3   0.1274  1.2754  ...  0.418840   -0.79602  0.59074    2.8787  7.6524
# 4  0.81682   1.515  ...  0.240400    0.10716  0.77048   0.13938  10.118
#
#    Attr61   Attr62  Attr63  Attr64  class
# 0  4.7343  142.760  2.5568  3.2597      0
# 1  3.2749  111.140  3.2841    3.37      0
# 2   2.987   71.531  5.1027  5.6188      0
# 3  3.3302  147.560  2.4735  5.9299      0
# 4   4.095  106.430  3.4294  3.3622      0
#
# [5 rows x 66 columns]

# %%
data.tail()
# Out:
#         id     Attr1    Attr2      Attr3    Attr4    Attr5     Attr6  \
# 5905  5906  0.012898  0.70621   0.038857   1.1722  -18.907         0
# 5906  5907  -0.57805  0.96702   -0.80085  0.16576  -67.365  -0.57805
# 5907  5908  -0.17905   1.2553   -0.27599  0.74554  -120.44  -0.17905
# 5908  5909  -0.10886  0.74394   0.015449   1.0878  -17.003  -0.10886
# 5909  5910  -0.10537  0.53629  -0.045578  0.91478  -56.068  -0.10537
#
#          Attr7     Attr8    Attr9  ...    Attr56    Attr57   Attr58  \
# 5905  0.013981     0.416   1.6768  ...  0.020169  0.043904  1.01220
# 5906  -0.57805  -0.40334  0.93979  ... -0.064073     1.482  1.06410
# 5907  -0.15493  -0.26018   1.1749  ...  0.148880   0.54824  0.85112
# 5908  -0.10918   0.12531  0.84516  ... -0.183200   -1.1677  1.18320
# 5909  -0.10994    0.8646   0.9504  ... -0.052186  -0.22725  1.05220
#
#          Attr59  Attr60  Attr61   Attr62  Attr63   Attr64  class
# 5905     1.2594  13.472  12.432   49.117  7.4313   2.2799      1
# 5906  -0.018084  110.72  44.759   81.220   4.494   5.1305      1
# 5907   -0.52243  9.8526  3.4892  207.870  1.7559   9.9527      1
# 5908     6.0924  13.886  6.0769   83.122  4.3911  0.95575      1
# 5909   0.003196  7.7332  4.7174  136.850  2.6672   2.7927      1
#
# [5 rows x 66 columns]

# %%
data_keys= list(data.keys())
len(data_keys)
# Out:
# 66

# %%
print(data.shape)
# Out:
# (5910, 66)

# %%
data.describe()
# Out:
#                 id       Attr13       Attr19       Attr20       Attr23  \
# count  5910.000000  5910.000000  5910.000000  5910.000000  5910.000000
# mean   2955.500000     0.354420    -0.090248    56.671984    -0.096856
# std    1706.214377    30.918776     5.444892   168.125493     5.418386
# min       1.000000  -310.340000  -310.800000   -29.340000  -310.890000
# 25%    1478.250000     0.024002     0.004098    18.280250     0.002571
# Attr31  0.177880  0.660896 -0.441907 -0.475291  0.668147  0.005771  0.155614
# Attr39  1.000000  0.363978 -0.257778 -0.253721  0.384044  0.015616  0.937166
# Attr42  0.363978  1.000000 -0.681998 -0.730260  0.973885  0.006925  0.306979
# Attr43 -0.257778 -0.681998  1.000000  0.978410 -0.702420 -0.003663 -0.187835
# Attr44 -0.253721 -0.730260  0.978410  1.000000 -0.749680 -0.004457 -0.178077
# Attr49  0.384044  0.973885 -0.702420 -0.749680  1.000000  0.008083  0.321641
# Attr55  0.015616  0.006925 -0.003663 -0.004457  0.008083  1.000000  0.019624
# Attr56  0.937166  0.306979 -0.187835 -0.178077  0.321641  0.019624  1.000000
# Attr58 -0.831626 -0.585483  0.406759  0.416791 -0.631204 -0.018405 -0.837101
# Attr62 -0.351467 -0.470239  0.557557  0.597063 -0.470692 -0.008999 -0.161767
# class  -0.100359 -0.023032  0.065923  0.058091 -0.025646 -0.041363 -0.087079
#
#           Attr58    Attr62     class
# id      0.042852  0.023316  0.440095
# Attr13  0.012340 -0.073858 -0.007330
# Attr19 -0.424713 -0.418476 -0.023425
# Attr20  0.108954  0.039069  0.058148
# Attr23 -0.421366 -0.418011 -0.023340
# Attr30  0.405466  0.952382  0.059472
# Attr31 -0.418853 -0.275953 -0.014602
# Attr39 -0.831626 -0.351467 -0.100359
# Attr42 -0.585483 -0.470239 -0.023032
# Attr43  0.406759  0.557557  0.065923
# Attr44  0.416791  0.597063  0.058091
# Attr49 -0.631204 -0.470692 -0.025646
# Attr55 -0.018405 -0.008999 -0.041363
# Attr56 -0.837101 -0.161767 -0.087079
# Attr58  1.000000  0.288514  0.066687
# Attr62  0.288514  1.000000  0.057565
# class   0.066687  0.057565  1.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5910 entries, 0 to 5909
# Data columns (total 66 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      5910 non-null   int64
#  1   Attr1   5910 non-null   object
#  2   Attr2   5910 non-null   object
#  3   Attr3   5910 non-null   object
#  4   Attr4   5910 non-null   object
#  5   Attr5   5910 non-null   object
#  6   Attr6   5910 non-null   object
#  7   Attr7   5910 non-null   object
#  8   Attr8   5910 non-null   object
#  9   Attr9   5910 non-null   object
#  10  Attr10  5910 non-null   object
#  11  Attr11  5910 non-null   object
#  12  Attr12  5910 non-null   object
#  13  Attr13  5910 non-null   float64
#  14  Attr14  5910 non-null   object
#  15  Attr15  5910 non-null   object
#  16  Attr16  5910 non-null   object
#  17  Attr17  5910 non-null   object
#  18  Attr18  5910 non-null   object
#  19  Attr19  5910 non-null   float64
#  20  Attr20  5910 non-null   float64
#  21  Attr21  5910 non-null   object
#  22  Attr22  5910 non-null   object
#  23  Attr23  5910 non-null   float64
#  24  Attr24  5910 non-null   object
#  25  Attr25  5910 non-null   object
#  26  Attr26  5910 non-null   object
#  27  Attr27  5910 non-null   object
#  28  Attr28  5910 non-null   object
#  29  Attr29  5910 non-null   object
#  30  Attr30  5910 non-null   float64
#  31  Attr31  5910 non-null   float64
#  32  Attr32  5910 non-null   object
#  33  Attr33  5910 non-null   object
#  34  Attr34  5910 non-null   object
#  35  Attr35  5910 non-null   object
#  36  Attr36  5910 non-null   object
#  37  Attr37  5910 non-null   object
#  38  Attr38  5910 non-null   object
#  39  Attr39  5910 non-null   float64
#  40  Attr40  5910 non-null   object
#  41  Attr41  5910 non-null   object
#  42  Attr42  5910 non-null   float64
#  43  Attr43  5910 non-null   float64
#  44  Attr44  5910 non-null   float64
#  45  Attr45  5910 non-null   object
#  46  Attr46  5910 non-null   object
#  47  Attr47  5910 non-null   object
#  48  Attr48  5910 non-null   object
#  49  Attr49  5910 non-null   float64
#  50  Attr50  5910 non-null   object
#  51  Attr51  5910 non-null   object
#  52  Attr52  5910 non-null   object
#  53  Attr53  5910 non-null   object
#  54  Attr54  5910 non-null   object
#  55  Attr55  5910 non-null   float64
#  56  Attr56  5910 non-null   float64
#  57  Attr57  5910 non-null   object
#  58  Attr58  5910 non-null   float64
#  59  Attr59  5910 non-null   object
#  60  Attr60  5910 non-null   object
#  61  Attr61  5910 non-null   object
#  62  Attr62  5910 non-null   float64
#  63  Attr63  5910 non-null   object
#  64  Attr64  5910 non-null   object
#  65  class   5910 non-null   int64
# dtypes: float64(15), int64(2), object(49)
# memory usage: 3.0+ MB

# %%
data.columns
# Out:
# Index(['id', 'Attr1', 'Attr2', 'Attr3', 'Attr4', 'Attr5', 'Attr6', 'Attr7',
#        'Attr8', 'Attr9', 'Attr10', 'Attr11', 'Attr12', 'Attr13', 'Attr14',
#        'Attr15', 'Attr16', 'Attr17', 'Attr18', 'Attr19', 'Attr20', 'Attr21',
#        'Attr22', 'Attr23', 'Attr24', 'Attr25', 'Attr26', 'Attr27', 'Attr28',
#        'Attr29', 'Attr30', 'Attr31', 'Attr32', 'Attr33', 'Attr34', 'Attr35',
#        'Attr36', 'Attr37', 'Attr38', 'Attr39', 'Attr40', 'Attr41', 'Attr42',
#        'Attr43', 'Attr44', 'Attr45', 'Attr46', 'Attr47', 'Attr48', 'Attr49',
#        'Attr50', 'Attr51', 'Attr52', 'Attr53', 'Attr54', 'Attr55', 'Attr56',
#        'Attr57', 'Attr58', 'Attr59', 'Attr60', 'Attr61', 'Attr62', 'Attr63',
#        'Attr64', 'class'],
#       dtype='object')

# %%
data['class'].value_counts()
# Out:
# 0    5500
# 1     410
# Name: class, dtype: int64

# %%
data.isna().sum()
# Out:
# id        0
# Attr1     0
# Attr2     0
# Attr3     0
# Attr4     0
#          ..
# Attr61    0
# Attr62    0
# Attr63    0
# Attr64    0
# class     0
# Length: 66, dtype: int64

# %%
data.hist( figsize=(18,18))
# Out:
# array([[<Axes: title={'center': 'id'}>,
#         <Axes: title={'center': 'Attr13'}>,
#         <Axes: title={'center': 'Attr19'}>,
#         <Axes: title={'center': 'Attr20'}>],
#        [<Axes: title={'center': 'Attr23'}>,
#         <Axes: title={'center': 'Attr30'}>,
#         <Axes: title={'center': 'Attr31'}>,
#         <Axes: title={'center': 'Attr39'}>],
#        [<Axes: title={'center': 'Attr42'}>,
#         <Axes: title={'center': 'Attr43'}>,
#         <Axes: title={'center': 'Attr44'}>,
#         <Axes: title={'center': 'Attr49'}>],
#        [<Axes: title={'center': 'Attr55'}>,
#         <Axes: title={'center': 'Attr56'}>,
#         <Axes: title={'center': 'Attr58'}>,
#         <Axes: title={'center': 'Attr62'}>],
#        [<Axes: title={'center': 'class'}>, <Axes: >, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
# Import label encoder
from sklearn import preprocessing

# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()

# Encode labels in column 'species'.
data['class']= label_encoder.fit_transform(data['class'])

data['class'].unique()
# Out:
# array([0, 1])

# %%
data['class'].value_counts() #verify => SAME AS BEFORE
# Out:
# 0    5500
# 1     410
# Name: class, dtype: int64

# %%
total_cells= np.product(data.shape)
total_missing=data.isnull().sum().sum()
# percent of data that is missing
percent_missing = (total_missing/total_cells) * 100
print(percent_missing)
# Out:
# 0.0

# %%
import missingno as msno
msno.matrix(data)
# Out:
# <Axes: >

# %%
fig, axe = plt.subplots(figsize=(30,20))
msno.heatmap(data,ax=axe)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/matrix.py:309: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# /usr/local/lib/python3.10/dist-packages/seaborn/matrix.py:309: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# <Axes: >

# %%
plt.figure(figsize=(50,60))
pltmv=sns.displot(data=data.isna().melt(value_name="missing"),
            y="variable",hue="missing",
            multiple="fill",height=10,aspect=1)
plt.savefig("visualizing_missing_data_with_barplot.png", dpi=100)

# %% [markdown]
# METHOD 1 knn Data Imputation -MISSING VALUE

# %%
d1= data.copy()

# %%
from sklearn.impute import KNNImputer

# Replace '?' with NaN in the DataFrame
d1.replace('?', np.nan, inplace=True)

# Assuming 'data_keys' contains the list of column names you want to impute
for i in data_keys:
    X = np.array(d1[i]).reshape(-1, 1)

    # Convert the column to float (including NaNs) before imputing
    X = X.astype(float)

    imputer = KNNImputer(n_neighbors=3)
    X_prep = imputer.fit_transform(X)

    # Assign the imputed values back to the DataFrame
    d1[i] = X_prep.reshape(1, -1)[0]

d1.head()
# Out:
#     id     Attr1    Attr2    Attr3   Attr4     Attr5     Attr6     Attr7  \
# 0  1.0  0.088238  0.55472  0.01134  1.0205  -66.5200  0.342040  0.109490
# 1  2.0 -0.006202  0.48465  0.23298  1.5998    6.1825  0.000000 -0.006202
# 2  3.0  0.130240  0.22142  0.57751  3.6082  120.0400  0.187640  0.162120
# 3  4.0 -0.089951  0.88700  0.26927  1.5222  -55.9920 -0.073957 -0.089951
# 4  5.0  0.048179  0.55041  0.10765  1.2437  -22.9590  0.000000  0.059280
#
#      Attr8   Attr9  ...    Attr56    Attr57   Attr58    Attr59   Attr60  \
# 0  0.57752  1.0881  ...  0.080955  0.275430  0.91905  0.002024   7.2711
# 1  1.06340  1.2757  ... -0.028591 -0.012035  1.00470  0.152220   6.0911
# 2  3.05900  1.1415  ...  0.123960  0.192290  0.87604  0.000000   8.7934
# 3  0.12740  1.2754  ...  0.418840 -0.796020  0.59074  2.878700   7.6524
# 4  0.81682  1.5150  ...  0.240400  0.107160  0.77048  0.139380  10.1180
#
#    Attr61   Attr62  Attr63  Attr64  class
# 0  4.7343  142.760  2.5568  3.2597    0.0
# 1  3.2749  111.140  3.2841  3.3700    0.0
# 2  2.9870   71.531  5.1027  5.6188    0.0
# 3  3.3302  147.560  2.4735  5.9299    0.0
# 4  4.0950  106.430  3.4294  3.3622    0.0
#
# [5 rows x 66 columns]

# %%
total_cells= np.product(d1.shape)
total_missing=d1.isnull().sum().sum()
# percent of data that is missing
percent_missing = (total_missing/total_cells) * 100
print(percent_missing)
# Out:
# 0.0

# %%
d1.describe()
# Out:
#                 id        Attr1        Attr2        Attr3        Attr4  \
# count  5910.000000  5910.000000  5910.000000  5910.000000  5910.000000
# mean   2955.500000    -0.022347     0.465086     0.189155     4.892476
# std    1706.214377     6.162090     5.749823     1.177430    91.271954
# min       1.000000  -463.890000  -430.870000   -72.067000    -0.403110
# 25%    1478.250000     0.003895     0.255370     0.043976     1.097200
# 50%    2955.500000     0.046657     0.452020     0.219360     1.657200
# 75%    4432.750000     0.117040     0.661530     0.418318     2.945700
# max    5910.000000    87.459000    72.416000    28.336000  6845.800000
#
#               Attr5        Attr6        Attr7        Attr8        Attr9  ...  \
# count  5.910000e+03  5910.000000  5910.000000  5910.000000  5910.000000  ...
# mean   1.940676e+01     0.022584    -0.111951     5.737741     1.588322  ...
# std    2.150927e+04     9.989544     9.054836   102.199085     1.548259  ...
# min   -1.076400e+06  -463.890000  -517.480000    -3.735100    -3.496000  ...
# 25%   -4.369900e+01     0.000000     0.005836     0.482790     1.014825  ...
# 50%    5.676050e-01     0.000000     0.056433     1.156050     1.139800  ...
# 75%    4.865500e+01     0.108490     0.136825     2.809725     1.825875  ...
# max    1.250100e+06   543.250000     5.530000  6868.500000    65.607000  ...
#
#             Attr56       Attr57       Attr58       Attr59        Attr60  \
# count  5910.000000  5910.000000  5910.000000  5910.000000  5.910000e+03
# mean      0.057222    -0.263837     0.956504     0.279319  9.110338e+02
# std       0.698096    18.420414     0.857326     5.839072  6.268296e+04
# min     -46.788000 -1236.300000    -0.164390  -184.980000 -1.244000e+01
# 25%       0.010996     0.015562     0.876552     0.000000  5.390000e+00
# 50%       0.053218     0.109645     0.950370     0.005723  9.451100e+00
# 75%       0.125085     0.242785     0.990405     0.205797  1.991800e+01
# max       1.651000    87.981000    47.788000   308.150000  4.818700e+06
#
#             Attr61         Attr62       Attr63         Attr64        class
# count  5910.000000    5910.000000  5910.000000    5910.000000  5910.000000
# mean     10.941497     241.978184     9.127741      65.276716     0.069374
# std      41.114307    6221.135690   102.890983    2131.084988     0.254110
# min      -0.092493    -236.530000    -1.543200      -3.726500     0.000000
# 25%       4.280125      44.646750     3.072575       2.176900     0.000000
# 50%       6.205350      73.778500     4.943100       4.224900     0.000000
# 75%       9.380950     118.720000     8.173025       9.872550     0.000000
# max    1308.500000  451380.000000  7641.300000  158180.000000     1.000000
#
# [8 rows x 66 columns]

# %%
#!pip install impyute
#from impyute.imputation.cs import mice
#d2=df.copy()
# start the MICE training
#imputed_training=mice(d2.values.astype(float))

# %%
sns.countplot(x=d1['class'])
plt.title('Target feature - Bankrupt class')
# Out:
# Text(0.5, 1.0, 'Target feature - Bankrupt class')

# %% [markdown]
# There is imbalance in the Target value, we need to oversample it based

# %% [markdown]
# OverSamppling :SMOTE

# %%
from imblearn.over_sampling import SMOTE

# %%
X=d1.drop(labels=['class'], axis=1)
y=d1['class']

# %%
oversample = SMOTE()
X,y=oversample.fit_resample(X,y)

# %%
sns.countplot(x=y)
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
data_x= pd.DataFrame(X,columns=data_keys[:len(data_keys)-1])
print(data_x.head())
#y class data
data_x.shape
# Out:
#     id     Attr1    Attr2    Attr3   Attr4     Attr5     Attr6     Attr7  \
# 0  1.0  0.088238  0.55472  0.01134  1.0205  -66.5200  0.342040  0.109490
# 1  2.0 -0.006202  0.48465  0.23298  1.5998    6.1825  0.000000 -0.006202
# 2  3.0  0.130240  0.22142  0.57751  3.6082  120.0400  0.187640  0.162120
# 3  4.0 -0.089951  0.88700  0.26927  1.5222  -55.9920 -0.073957 -0.089951
# 4  5.0  0.048179  0.55041  0.10765  1.2437  -22.9590  0.000000  0.059280
#
#      Attr8   Attr9  ...      Attr55    Attr56    Attr57   Attr58    Attr59  \
# 0  0.57752  1.0881  ...  15182.0000  0.080955  0.275430  0.91905  0.002024
# 1  1.06340  1.2757  ...   2341.8000 -0.028591 -0.012035  1.00470  0.152220
# 2  3.05900  1.1415  ...  33401.0000  0.123960  0.192290  0.87604  0.000000
# 3  0.12740  1.2754  ...   2789.6000  0.418840 -0.796020  0.59074  2.878700
# 4  0.81682  1.5150  ...      1.2437  0.240400  0.107160  0.77048  0.139380
#
#     Attr60  Attr61   Attr62  Attr63  Attr64
# 0   7.2711  4.7343  142.760  2.5568  3.2597
# 1   6.0911  3.2749  111.140  3.2841  3.3700
# 2   8.7934  2.9870   71.531  5.1027  5.6188
# 3   7.6524  3.3302  147.560  2.4735  5.9299
# 4  10.1180  4.0950  106.430  3.4294  3.3622
#
# [5 rows x 65 columns]
# (11000, 65)

# %%
data.head()
# Out:
#    id      Attr1    Attr2    Attr3   Attr4    Attr5      Attr6      Attr7  \
# 0   1   0.088238  0.55472  0.01134  1.0205   -66.52    0.34204    0.10949
# 1   2  -0.006202  0.48465  0.23298  1.5998   6.1825          0  -0.006202
# 2   3    0.13024  0.22142  0.57751  3.6082   120.04    0.18764    0.16212
# 3   4  -0.089951    0.887  0.26927  1.5222  -55.992  -0.073957  -0.089951
# 4   5   0.048179  0.55041  0.10765  1.2437  -22.959          0    0.05928
#
#      Attr8   Attr9  ...    Attr56     Attr57   Attr58    Attr59  Attr60  \
# 0  0.57752  1.0881  ...  0.080955    0.27543  0.91905  0.002024  7.2711
# 1   1.0634  1.2757  ... -0.028591  -0.012035  1.00470   0.15222  6.0911
# 2    3.059  1.1415  ...  0.123960    0.19229  0.87604         0  8.7934
# 3   0.1274  1.2754  ...  0.418840   -0.79602  0.59074    2.8787  7.6524
# 4  0.81682   1.515  ...  0.240400    0.10716  0.77048   0.13938  10.118
#
#    Attr61   Attr62  Attr63  Attr64  class
# 0  4.7343  142.760  2.5568  3.2597      0
# 1  3.2749  111.140  3.2841    3.37      0
# 2   2.987   71.531  5.1027  5.6188      0
# 3  3.3302  147.560  2.4735  5.9299      0
# 4   4.095  106.430  3.4294  3.3622      0
#
# [5 rows x 66 columns]
