# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/content/drive/MyDrive/csv_result-4year.csv')
# Out:
# <ipython-input-2-701eb514733c>:1: DtypeWarning: Columns (1,2,3,6,7,8,10,11,14,15,16,17,18,22,24,25,26,29,34,35,36,38,48,50,51,57,59) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv('/content/drive/MyDrive/csv_result-4year.csv')

# %%
data
# Out:
#         id     Attr1    Attr2     Attr3    Attr4    Attr5       Attr6  \
# 0        1   0.15929   0.4624   0.07773   1.1683  -44.853     0.46702
# 1        2  -0.12743  0.46243   0.26917   1.7517    7.597  0.00092515
# 2        3  0.070488   0.2357   0.52781   3.2393   125.68     0.16367
# 3        4   0.13676  0.40538   0.31543   1.8705   19.115     0.50497
# 4        5  -0.11008  0.69793   0.18878   1.2713  -15.344           0
# ...    ...       ...      ...       ...      ...      ...         ...
# 9787  9788  0.004676  0.54949   0.19281   1.3899  -39.064    0.004676
# 9788  9789  -0.02761  0.60748 -0.029762  0.90591  -20.923    -0.02761
# 9789  9790  -0.23829  0.62708  0.090374   1.6125  -1.0692    -0.23829
# 9790  9791  0.097188    0.753  -0.32768   0.4385  -214.24     -0.3313
# 9791  9792  0.021416  0.48678   0.14894   1.3067  -24.282    0.021416
#
#          Attr7    Attr8    Attr9  ...     Attr56     Attr57   Attr58  \
# 0      0.18948  0.82895  1.12230  ...    0.10899    0.41557  0.89101
# 1     -0.12743   1.1625  1.29440  ...  -0.089372   -0.23704   1.0625
# 2     0.086895   2.8718  1.05740  ...   0.054286    0.10413  0.94571
# 3      0.13676   1.4539  1.11440  ...    0.10263    0.23203  0.89737
# 4     -0.11008  0.43282  1.73500  ...    0.43988    -0.3644  0.57153
# ...        ...      ...      ...  ...        ...        ...      ...
# 9787  0.013002  0.78627  0.97093  ...  -0.029937   0.010823   1.0299
# 9788  -0.02761  0.55161  1.00730  ...   0.007198  -0.082395   0.9928
# 9789  -0.24036  0.28322  0.80307  ...   -0.24522    -1.3417   1.2452
# 9790   0.10428  0.32803  0.98145  ...    0.28824    0.39347  0.68127
# 9791  0.027253   1.0532  1.00140  ...  0.0013932   0.041773  0.99861
#
#          Attr59  Attr60  Attr61  Attr62  Attr63   Attr64 class
# 0      0.001422  7.7928  4.9914  119.81  3.0465    3.056     0
# 1       0.15041  5.4327  3.4629  100.97   3.615   3.4725     0
# 2           0.0   7.107  3.3808  76.076  4.7978   4.7818     0
# 3      0.073024  6.1384  4.2241  88.299  4.1337   4.6484     0
# 4           0.0  18.801  2.7925  146.39  2.4934   15.036     0
# ...         ...     ...     ...     ...     ...      ...   ...
# 9787    0.12719  3.8159  3.3892  146.86  2.4854   3.9315     1
# 9788    0.86891  23.028  27.136  37.047  9.8523   4.3681     1
# 9789     2.7001  6.5694  4.1781  88.883  4.1065  0.79501     1
# 9790    0.50885  4.3246  35.503  217.03  1.6818   1.3191     1
# 9791  0.0021459  6.7582  4.9171  98.421  3.7085   4.9295     1
#
# [9792 rows x 66 columns]

# %%
data.tail()
# Out:
#         id     Attr1    Attr2     Attr3    Attr4    Attr5     Attr6     Attr7  \
# 9787  9788  0.004676  0.54949   0.19281   1.3899  -39.064  0.004676  0.013002
# 9788  9789  -0.02761  0.60748 -0.029762  0.90591  -20.923  -0.02761  -0.02761
# 9789  9790  -0.23829  0.62708  0.090374   1.6125  -1.0692  -0.23829  -0.24036
# 9790  9791  0.097188    0.753  -0.32768   0.4385  -214.24   -0.3313   0.10428
# 9791  9792  0.021416  0.48678   0.14894   1.3067  -24.282  0.021416  0.027253
#
#         Attr8    Attr9  ...     Attr56     Attr57   Attr58     Attr59  Attr60  \
# 9787  0.78627  0.97093  ...  -0.029937   0.010823   1.0299    0.12719  3.8159
# 9788  0.55161  1.00730  ...   0.007198  -0.082395   0.9928    0.86891  23.028
# 9789  0.28322  0.80307  ...   -0.24522    -1.3417   1.2452     2.7001  6.5694
# 9790  0.32803  0.98145  ...    0.28824    0.39347  0.68127    0.50885  4.3246
# 9791   1.0532  1.00140  ...  0.0013932   0.041773  0.99861  0.0021459  6.7582
#
#       Attr61  Attr62  Attr63   Attr64 class
# 9787  3.3892  146.86  2.4854   3.9315     1
# 9788  27.136  37.047  9.8523   4.3681     1
# 9789  4.1781  88.883  4.1065  0.79501     1
# 9790  35.503  217.03  1.6818   1.3191     1
# 9791  4.9171  98.421  3.7085   4.9295     1
#
# [5 rows x 66 columns]

# %%
data.head()
# Out:
#    id     Attr1    Attr2    Attr3   Attr4    Attr5       Attr6     Attr7  \
# 0   1   0.15929   0.4624  0.07773  1.1683  -44.853     0.46702   0.18948
# 1   2  -0.12743  0.46243  0.26917  1.7517    7.597  0.00092515  -0.12743
# 2   3  0.070488   0.2357  0.52781  3.2393   125.68     0.16367  0.086895
# 3   4   0.13676  0.40538  0.31543  1.8705   19.115     0.50497   0.13676
# 4   5  -0.11008  0.69793  0.18878  1.2713  -15.344           0  -0.11008
#
#      Attr8   Attr9  ...     Attr56   Attr57   Attr58    Attr59  Attr60  \
# 0  0.82895  1.1223  ...    0.10899  0.41557  0.89101  0.001422  7.7928
# 1   1.1625  1.2944  ...  -0.089372 -0.23704   1.0625   0.15041  5.4327
# 2   2.8718  1.0574  ...   0.054286  0.10413  0.94571       0.0   7.107
# 3   1.4539  1.1144  ...    0.10263  0.23203  0.89737  0.073024  6.1384
# 4  0.43282  1.7350  ...    0.43988  -0.3644  0.57153       0.0  18.801
#
#    Attr61  Attr62  Attr63  Attr64 class
# 0  4.9914  119.81  3.0465   3.056     0
# 1  3.4629  100.97   3.615  3.4725     0
# 2  3.3808  76.076  4.7978  4.7818     0
# 3  4.2241  88.299  4.1337  4.6484     0
# 4  2.7925  146.39  2.4934  15.036     0
#
# [5 rows x 66 columns]

# %%
data_keys= list(data.keys())
len(data_keys)
# Out:
# 66

# %%
print(data.shape)
# Out:
# (9792, 66)

# %%
data.describe()
# Out:
#                 id        Attr9        Attr55        class
# count  9792.000000  9792.000000  9.792000e+03  9792.000000
# mean   4896.500000     1.882296  7.686330e+03     0.052594
# std    2826.851252    17.674650  7.605261e+04     0.223233
# min       1.000000    -0.032371 -7.132200e+05     0.000000
# 25%    2448.750000     1.006675  2.184000e+01     0.000000
# 50%    4896.500000     1.161300  9.503300e+02     0.000000
# 75%    7344.250000     1.970225  4.694550e+03     0.000000
# max    9792.000000  1704.800000  6.123700e+06     1.000000

# %%
data.describe().transpose()
# Out:
#          count         mean           std            min          25%  \
# id      9792.0  4896.500000   2826.851252       1.000000  2448.750000
# Attr9   9792.0     1.882296     17.674650      -0.032371     1.006675
# Attr55  9792.0  7686.329947  76052.607701 -713220.000000    21.840000
# class   9792.0     0.052594      0.223233       0.000000     0.000000
#
#               50%          75%        max
# id      4896.5000  7344.250000     9792.0
# Attr9      1.1613     1.970225     1704.8
# Attr55   950.3300  4694.550000  6123700.0
# class      0.0000     0.000000        1.0

# %%
data.corr()
# Out:
# <ipython-input-10-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#               id     Attr9    Attr55     class
# id      1.000000 -0.002562 -0.004420  0.386631
# Attr9  -0.002562  1.000000 -0.003395  0.000905
# Attr55 -0.004420 -0.003395  1.000000 -0.020868
# class   0.386631  0.000905 -0.020868  1.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9792 entries, 0 to 9791
# Data columns (total 66 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      9792 non-null   int64
#  1   Attr1   9792 non-null   object
#  2   Attr2   9792 non-null   object
#  3   Attr3   9792 non-null   object
#  4   Attr4   9792 non-null   object
#  5   Attr5   9792 non-null   object
#  6   Attr6   9792 non-null   object
#  7   Attr7   9792 non-null   object
#  8   Attr8   9792 non-null   object
#  9   Attr9   9792 non-null   float64
#  10  Attr10  9792 non-null   object
#  11  Attr11  9792 non-null   object
#  12  Attr12  9792 non-null   object
#  13  Attr13  9792 non-null   object
#  14  Attr14  9792 non-null   object
#  15  Attr15  9792 non-null   object
#  16  Attr16  9792 non-null   object
#  17  Attr17  9792 non-null   object
#  18  Attr18  9792 non-null   object
#  19  Attr19  9792 non-null   object
#  20  Attr20  9792 non-null   object
#  21  Attr21  9792 non-null   object
#  22  Attr22  9792 non-null   object
#  23  Attr23  9792 non-null   object
#  24  Attr24  9792 non-null   object
#  25  Attr25  9792 non-null   object
#  26  Attr26  9792 non-null   object
#  27  Attr27  9792 non-null   object
#  28  Attr28  9792 non-null   object
#  29  Attr29  9792 non-null   object
#  30  Attr30  9792 non-null   object
#  31  Attr31  9792 non-null   object
#  32  Attr32  9792 non-null   object
#  33  Attr33  9792 non-null   object
#  34  Attr34  9792 non-null   object
#  35  Attr35  9792 non-null   object
#  36  Attr36  9792 non-null   object
#  37  Attr37  9792 non-null   object
#  38  Attr38  9792 non-null   object
#  39  Attr39  9792 non-null   object
#  40  Attr40  9792 non-null   object
#  41  Attr41  9792 non-null   object
#  42  Attr42  9792 non-null   object
#  43  Attr43  9792 non-null   object
#  44  Attr44  9792 non-null   object
#  45  Attr45  9792 non-null   object
#  46  Attr46  9792 non-null   object
#  47  Attr47  9792 non-null   object
#  48  Attr48  9792 non-null   object
#  49  Attr49  9792 non-null   object
#  50  Attr50  9792 non-null   object
#  51  Attr51  9792 non-null   object
#  52  Attr52  9792 non-null   object
#  53  Attr53  9792 non-null   object
#  54  Attr54  9792 non-null   object
#  55  Attr55  9792 non-null   float64
#  56  Attr56  9792 non-null   object
#  57  Attr57  9792 non-null   object
#  58  Attr58  9792 non-null   object
#  59  Attr59  9792 non-null   object
#  60  Attr60  9792 non-null   object
#  61  Attr61  9792 non-null   object
#  62  Attr62  9792 non-null   object
#  63  Attr63  9792 non-null   object
#  64  Attr64  9792 non-null   object
#  65  class   9792 non-null   int64
# dtypes: float64(2), int64(2), object(62)
# memory usage: 4.9+ MB

# %%
data.columns
# Out:
# Index(['id', 'Attr1', 'Attr2', 'Attr3', 'Attr4', 'Attr5', 'Attr6', 'Attr7',
#        'Attr8', 'Attr9', 'Attr10', 'Attr11', 'Attr12', 'Attr13', 'Attr14',
#        'Attr15', 'Attr16', 'Attr17', 'Attr18', 'Attr19', 'Attr20', 'Attr21',
#        'Attr22', 'Attr23', 'Attr24', 'Attr25', 'Attr26', 'Attr27', 'Attr28',
#        'Attr29', 'Attr30', 'Attr31', 'Attr32', 'Attr33', 'Attr34', 'Attr35',
#        'Attr36', 'Attr37', 'Attr38', 'Attr39', 'Attr40', 'Attr41', 'Attr42',
#        'Attr43', 'Attr44', 'Attr45', 'Attr46', 'Attr47', 'Attr48', 'Attr49',
#        'Attr50', 'Attr51', 'Attr52', 'Attr53', 'Attr54', 'Attr55', 'Attr56',
#        'Attr57', 'Attr58', 'Attr59', 'Attr60', 'Attr61', 'Attr62', 'Attr63',
#        'Attr64', 'class'],
#       dtype='object')

# %%
data['class'].value_counts()
# Out:
# 0    9277
# 1     515
# Name: class, dtype: int64

# %%
data.isna().sum()
# Out:
# id        0
# Attr1     0
# Attr2     0
# Attr3     0
# Attr4     0
#          ..
# Attr61    0
# Attr62    0
# Attr63    0
# Attr64    0
# class     0
# Length: 66, dtype: int64

# %%
data.hist( figsize=(18,18))
# Out:
# array([[<Axes: title={'center': 'id'}>,
#         <Axes: title={'center': 'Attr9'}>],
#        [<Axes: title={'center': 'Attr55'}>,
#         <Axes: title={'center': 'class'}>]], dtype=object)

# %%
# Import label encoder
from sklearn import preprocessing

# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()

# Encode labels in column 'species'.
data['class']= label_encoder.fit_transform(data['class'])

data['class'].unique()
# Out:
# array([0, 1])

# %%
data['class'].value_counts() #verify => SAME AS BEFORE
# Out:
# 0    9277
# 1     515
# Name: class, dtype: int64

# %%
total_cells= np.product(data.shape)
total_missing=data.isnull().sum().sum()
# percent of data that is missing
percent_missing = (total_missing/total_cells) * 100
print(percent_missing)
# Out:
# 0.0

# %%
import missingno as msno
msno.matrix(data)
# Out:
# <Axes: >

# %%
fig, axe = plt.subplots(figsize=(30,20))
msno.heatmap(data,ax=axe)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/matrix.py:309: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# /usr/local/lib/python3.10/dist-packages/seaborn/matrix.py:309: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# <Axes: >

# %%
plt.figure(figsize=(50,60))
pltmv=sns.displot(data=data.isna().melt(value_name="missing"),
            y="variable",hue="missing",
            multiple="fill",height=10,aspect=1)
plt.savefig("visualizing_missing_data_with_barplot.png", dpi=100)

# %% [markdown]
# METHOD 1 knn Data Imputation -MISSING VALUE

# %%
d1= data.copy()

# %%
from sklearn.impute import KNNImputer

# Replace '?' with NaN in the DataFrame
d1.replace('?', np.nan, inplace=True)

# Assuming 'data_keys' contains the list of column names you want to impute
for i in data_keys:
    X = np.array(d1[i]).reshape(-1, 1)

    # Convert the column to float (including NaNs) before imputing
    X = X.astype(float)

    imputer = KNNImputer(n_neighbors=3)
    X_prep = imputer.fit_transform(X)

    # Assign the imputed values back to the DataFrame
    d1[i] = X_prep.reshape(1, -1)[0]

d1.head()
# Out:
#     id     Attr1    Attr2    Attr3   Attr4    Attr5     Attr6     Attr7  \
# 0  1.0  0.159290  0.46240  0.07773  1.1683  -44.853  0.467020  0.189480
# 1  2.0 -0.127430  0.46243  0.26917  1.7517    7.597  0.000925 -0.127430
# 2  3.0  0.070488  0.23570  0.52781  3.2393  125.680  0.163670  0.086895
# 3  4.0  0.136760  0.40538  0.31543  1.8705   19.115  0.504970  0.136760
# 4  5.0 -0.110080  0.69793  0.18878  1.2713  -15.344  0.000000 -0.110080
#
#      Attr8   Attr9  ...    Attr56   Attr57   Attr58    Attr59   Attr60  \
# 0  0.82895  1.1223  ...  0.108990  0.41557  0.89101  0.001422   7.7928
# 1  1.16250  1.2944  ... -0.089372 -0.23704  1.06250  0.150410   5.4327
# 2  2.87180  1.0574  ...  0.054286  0.10413  0.94571  0.000000   7.1070
# 3  1.45390  1.1144  ...  0.102630  0.23203  0.89737  0.073024   6.1384
# 4  0.43282  1.7350  ...  0.439880 -0.36440  0.57153  0.000000  18.8010
#
#    Attr61   Attr62  Attr63   Attr64  class
# 0  4.9914  119.810  3.0465   3.0560    0.0
# 1  3.4629  100.970  3.6150   3.4725    0.0
# 2  3.3808   76.076  4.7978   4.7818    0.0
# 3  4.2241   88.299  4.1337   4.6484    0.0
# 4  2.7925  146.390  2.4934  15.0360    0.0
#
# [5 rows x 66 columns]

# %%
total_cells= np.product(d1.shape)
total_missing=d1.isnull().sum().sum()
# percent of data that is missing
percent_missing = (total_missing/total_cells) * 100
print(percent_missing)
# Out:
# 0.0

# %%
d1.describe()
# Out:
#                 id        Attr1        Attr2        Attr3         Attr4  \
# count  9792.000000  9792.000000  9792.000000  9792.000000   9792.000000
# mean   4896.500000     0.043019     0.596404     0.130959      8.136600
# std    2826.851252     0.359303     4.586887     4.558841    290.008348
# min       1.000000   -12.458000     0.000000  -445.910000     -0.045319
# 25%    2448.750000     0.001322     0.263163     0.020384      1.048500
# 50%    4896.500000     0.041374     0.467770     0.199290      1.598750
# 75%    7344.250000     0.111125     0.689183     0.410635      2.917825
# max    9792.000000    20.482000   446.910000    22.769000  27146.000000
#
#               Attr5        Attr6        Attr7         Attr8        Attr9  ...  \
# count  9.792000e+03  9792.000000  9792.000000   9792.000000  9792.000000  ...
# mean   6.465164e+01    -0.059273     0.059446     19.884016     1.882296  ...
# std    1.474355e+04     6.812406     0.533317    698.018755    17.674650  ...
# min   -3.794600e+05  -486.820000   -12.458000     -1.848200    -0.032371  ...
# 25%   -5.100925e+01    -0.000591     0.003005      0.428932     1.006675  ...
# 50%    0.000000e+00     0.000000     0.048840      1.092450     1.161300  ...
# 75%    5.626250e+01     0.065245     0.126930      2.701450     1.970225  ...
# max    1.034100e+06   322.200000    38.618000  53209.000000  1704.800000  ...
#
#             Attr56       Attr57       Attr58       Attr59         Attr60  \
# count  9792.000000  9792.000000  9792.000000  9792.000000    9792.000000
# mean     -0.992263     0.035022     1.133287     0.856053     118.156064
# std      76.925343     8.944908     8.031631    26.391957    3127.389272
# min   -7522.100000  -597.420000   -30.892000  -284.380000       0.000000
# 25%       0.002797     0.008781     0.886158     0.000000       5.557450
# 50%       0.043406     0.098026     0.958440     0.002138      10.253000
# 75%       0.117017     0.242615     0.996300     0.212020      24.102250
# max     112.020000   226.760000   668.750000  1661.000000  251570.000000
#
#               Attr61        Attr62       Attr63        Attr64        class
# count    9792.000000  9.792000e+03  9792.000000   9792.000000  9792.000000
# mean       25.194430  2.015157e+03     8.660813     35.949619     0.052594
# std      1097.462990  1.170204e+05    60.704460    477.583101     0.223233
# min       -12.656000 -1.496500e+04    -0.024390     -0.000015     0.000000
# 25%         4.272550  4.328575e+01     2.948850      2.049375     0.000000
# 50%         6.297050  7.494250e+01     4.870050      4.179500     0.000000
# 75%         9.982775  1.237625e+02     8.424000     10.337500     0.000000
# max    108000.000000  1.077900e+07  5662.400000  21153.000000     1.000000
#
# [8 rows x 66 columns]

# %%
#!pip install impyute
#from impyute.imputation.cs import mice
#d2=df.copy()
# start the MICE training
#imputed_training=mice(d2.values.astype(float))

# %%
sns.countplot(x=d1['class'])
plt.title('Target feature - Bankrupt class')
# Out:
# Text(0.5, 1.0, 'Target feature - Bankrupt class')

# %% [markdown]
# There is imbalance in the Target value, we need to oversample it based

# %% [markdown]
# OverSamppling :SMOTE

# %%
from imblearn.over_sampling import SMOTE

# %%
X=d1.drop(labels=['class'], axis=1)
y=d1['class']

# %%
oversample = SMOTE()
X,y=oversample.fit_resample(X,y)

# %%
sns.countplot(x=y)
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
data_x= pd.DataFrame(X,columns=data_keys[:len(data_keys)-1])
print(data_x.head())
#y class data
data_x.shape
# Out:
#     id     Attr1    Attr2    Attr3   Attr4    Attr5     Attr6     Attr7  \
# 0  1.0  0.159290  0.46240  0.07773  1.1683  -44.853  0.467020  0.189480
# 1  2.0 -0.127430  0.46243  0.26917  1.7517    7.597  0.000925 -0.127430
# 2  3.0  0.070488  0.23570  0.52781  3.2393  125.680  0.163670  0.086895
# 3  4.0  0.136760  0.40538  0.31543  1.8705   19.115  0.504970  0.136760
# 4  5.0 -0.110080  0.69793  0.18878  1.2713  -15.344  0.000000 -0.110080
#
#      Attr8   Attr9  ...   Attr55    Attr56   Attr57   Attr58    Attr59  \
# 0  0.82895  1.1223  ...  90533.0  0.108990  0.41557  0.89101  0.001422
# 1  1.16250  1.2944  ...   2624.9 -0.089372 -0.23704  1.06250  0.150410
# 2  2.87180  1.0574  ...  24672.0  0.054286  0.10413  0.94571  0.000000
# 3  1.45390  1.1144  ...   6649.9  0.102630  0.23203  0.89737  0.073024
# 4  0.43282  1.7350  ...   1314.0  0.439880 -0.36440  0.57153  0.000000
#
#     Attr60  Attr61   Attr62  Attr63   Attr64
# 0   7.7928  4.9914  119.810  3.0465   3.0560
# 1   5.4327  3.4629  100.970  3.6150   3.4725
# 2   7.1070  3.3808   76.076  4.7978   4.7818
# 3   6.1384  4.2241   88.299  4.1337   4.6484
# 4  18.8010  2.7925  146.390  2.4934  15.0360
#
# [5 rows x 65 columns]
# (18554, 65)

# %%
data.head()
# Out:
#    id     Attr1    Attr2    Attr3   Attr4    Attr5       Attr6     Attr7  \
# 0   1   0.15929   0.4624  0.07773  1.1683  -44.853     0.46702   0.18948
# 1   2  -0.12743  0.46243  0.26917  1.7517    7.597  0.00092515  -0.12743
# 2   3  0.070488   0.2357  0.52781  3.2393   125.68     0.16367  0.086895
# 3   4   0.13676  0.40538  0.31543  1.8705   19.115     0.50497   0.13676
# 4   5  -0.11008  0.69793  0.18878  1.2713  -15.344           0  -0.11008
#
#      Attr8   Attr9  ...     Attr56   Attr57   Attr58    Attr59  Attr60  \
# 0  0.82895  1.1223  ...    0.10899  0.41557  0.89101  0.001422  7.7928
# 1   1.1625  1.2944  ...  -0.089372 -0.23704   1.0625   0.15041  5.4327
# 2   2.8718  1.0574  ...   0.054286  0.10413  0.94571       0.0   7.107
# 3   1.4539  1.1144  ...    0.10263  0.23203  0.89737  0.073024  6.1384
# 4  0.43282  1.7350  ...    0.43988  -0.3644  0.57153       0.0  18.801
#
#    Attr61  Attr62  Attr63  Attr64 class
# 0  4.9914  119.81  3.0465   3.056     0
# 1  3.4629  100.97   3.615  3.4725     0
# 2  3.3808  76.076  4.7978  4.7818     0
# 3  4.2241  88.299  4.1337  4.6484     0
# 4  2.7925  146.39  2.4934  15.036     0
#
# [5 rows x 66 columns]
